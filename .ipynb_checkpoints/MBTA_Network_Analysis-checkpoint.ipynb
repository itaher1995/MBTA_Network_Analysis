# %% [markdown]
# What we need:
# * Refine efficiency measure
# * Develop null models (for all layers or just monoplex?)
# * Create visualization

# %%
import numpy as np
import pandas as pd
import requests
import json
import re
import networkx as nx
#import ggplot
import matplotlib.pyplot as plt
import random
#from geopy.distance import great_circle, vincenty
#from haversine import haversine
import itertools
import random
import time
import collections
import powerlaw
from multiprocessing import Pool
# %matplotlib inline

# %%
#API Call
url = "http://realtime.mbta.com/developer/api/v2/routes"

querystring = {"api_key":"cgb4DBBwS0GKb7HM4y05bA","format":"json"}

headers = {
    'cache-control': "no-cache",
    'postman-token': "4c7b8b89-58b4-c8f5-2509-0647e1775340"
    }

response = requests.request("GET", url, headers=headers, params=querystring)
routes=response.json()
#Route Types: Subway, Commuter Rail, Bus

#Separation of Types of Route
subwayRouteID=[[y['route_id'] for y in x['route']] for x in routes['mode'] if x['mode_name']=='Subway']
subwayRouteID=[y for x in subwayRouteID for y in x]
crRouteID=[[y['route_id'] for y in x['route']] for x in routes['mode'] if x['mode_name']=='Commuter Rail']
crRouteID=[y for x in crRouteID for y in x]
busRouteID=[[y['route_id'] for y in x['route']] for x in routes['mode'] if x['mode_name']=='Bus']
busRouteID=[y for x in busRouteID for y in x]


routesDic={'Subway':{subkey:[] for subkey in subwayRouteID},'Bus':{buskey:[] for buskey in busRouteID},'Commuter Rail':{crkey:[] for crkey in crRouteID}}

#get the stops for each route

for key in routesDic:
    for route in routesDic[key]:
        url = "http://realtime.mbta.com/developer/api/v2/stopsbyroute"
        querystring = {"api_key":"cgb4DBBwS0GKb7HM4y05bA","route":route,"format":"json"}
        headers = {
            'cache-control': "no-cache",
            'postman-token': "014e80a3-7552-8a15-6796-afa8e81495f3"
            }
        response = requests.request("GET", url, headers=headers, params=querystring)
        stops=response.json()
        routesDic[key][route]=[[re.sub(r'(.*) - .*',r'\1',x['stop_name']).replace(' Busway','').replace(' Lower','').replace(' Upper','')+'_{0}'.format(route),(float(x['stop_lon']),float(x['stop_lat']))] for x in stops['direction'][0]['stop']]
        if key=='Subway':
            routesDic[key][route]=[[re.sub(r'(.*) - .*',r'\1',x[0]).replace(' Orange Line',''),x[1]] for x in routesDic[key][route]]
        else:
            routesDic[key][route]=[[re.sub(r'(.*) - .*',r'\1',x[0]).replace(' Station',''),x[1]] for x in routesDic[key][route] if 'South' not in x and 'North' not in x]

#separate Ashmont and Braintree lines
routesDic['Subway']['Red-Ashmont']=routesDic['Subway']['Red'][:15]+routesDic['Subway']['Red'][16:21]
routesDic['Subway']['Red-Braintree']=routesDic['Subway']['Red'][:16]+routesDic['Subway']['Red'][21:-1]
routesDic['Subway']['Red-Ashmont'][-5][0]='JFK/UMASS_Red-Ashmont'
routesDic['Subway']['Red-Braintree'][-12][0]='JFK/UMASS_Red-Braintree'
del routesDic['Subway']['Red']

# %%
#create adjacency lists for each stop with lat, long data
subwayStops=[routesDic['Subway'][key] for key in routesDic['Subway']]
subwayStops=np.unique([y[0] for x in subwayStops for y in x])
subwayAdjacencyList={key:[] for key in subwayStops}
for route in routesDic['Subway']:
    for i in range(len(routesDic['Subway'][route])):
        if i==0:
            if routesDic['Subway'][route][i+1] not in subwayAdjacencyList[routesDic['Subway'][route][i][0]]:
                subwayAdjacencyList[routesDic['Subway'][route][i][0]].append(routesDic['Subway'][route][i+1])
        elif i>0 and i<(len(routesDic['Subway'][route])-2):
            if routesDic['Subway'][route][i-1] not in subwayAdjacencyList[routesDic['Subway'][route][i][0]]:
                subwayAdjacencyList[routesDic['Subway'][route][i][0]].append(routesDic['Subway'][route][i-1])
            if routesDic['Subway'][route][i+1] not in subwayAdjacencyList[routesDic['Subway'][route][i][0]]:
                subwayAdjacencyList[routesDic['Subway'][route][i][0]].append(routesDic['Subway'][route][i+1])
        else:
            subwayAdjacencyList[routesDic['Subway'][route][i][0]].append(routesDic['Subway'][route][i-1])
            subwayAdjacencyList[routesDic['Subway'][route][i-1][0]].append(routesDic['Subway'][route][i])

# %%
#create adjacency list for bus
busStops=[routesDic['Bus'][key] for key in routesDic['Bus']]
busStops=np.unique([y[0] for x in busStops for y in x])
busAdjacencyList={key:[] for key in busStops}
for route in routesDic['Bus']:
    for i in range(len(routesDic['Bus'][route])):
        if i==0:
            if routesDic['Bus'][route][i+1] not in busAdjacencyList[routesDic['Bus'][route][i][0]]:
                busAdjacencyList[routesDic['Bus'][route][i][0]].append(routesDic['Bus'][route][i+1])
        elif i>0 and i<(len(routesDic['Bus'][route])-2):
            if routesDic['Bus'][route][i-1] not in busAdjacencyList[routesDic['Bus'][route][i][0]]:
                busAdjacencyList[routesDic['Bus'][route][i][0]].append(routesDic['Bus'][route][i-1])
            if routesDic['Bus'][route][i+1] not in busAdjacencyList[routesDic['Bus'][route][i][0]]:
                busAdjacencyList[routesDic['Bus'][route][i][0]].append(routesDic['Bus'][route][i+1])
        else:
            busAdjacencyList[routesDic['Bus'][route][i][0]].append(routesDic['Bus'][route][i-1])
            busAdjacencyList[routesDic['Bus'][route][i-1][0]].append(routesDic['Bus'][route][i])

# %%
#create adjacency list for commuter rail
crStops=[routesDic['Commuter Rail'][key] for key in routesDic['Commuter Rail']]
crStops=np.unique([y[0] for x in crStops for y in x])
crAdjacencyList={key:[] for key in crStops}
for route in routesDic['Commuter Rail']:
    for i in range(len(routesDic['Commuter Rail'][route])):
        if i==0:
            if routesDic['Commuter Rail'][route][i+1] not in crAdjacencyList[routesDic['Commuter Rail'][route][i][0]]:
                crAdjacencyList[routesDic['Commuter Rail'][route][i][0]].append(routesDic['Commuter Rail'][route][i+1])
        elif i>0 and i<(len(routesDic['Commuter Rail'][route])-2):
            if routesDic['Commuter Rail'][route][i-1] not in crAdjacencyList[routesDic['Commuter Rail'][route][i][0]]:
                crAdjacencyList[routesDic['Commuter Rail'][route][i][0]].append(routesDic['Commuter Rail'][route][i-1])
            if routesDic['Commuter Rail'][route][i+1] not in crAdjacencyList[routesDic['Commuter Rail'][route][i][0]]:
                crAdjacencyList[routesDic['Commuter Rail'][route][i][0]].append(routesDic['Commuter Rail'][route][i+1])
        else:
            crAdjacencyList[routesDic['Commuter Rail'][route][i][0]].append(routesDic['Commuter Rail'][route][i-1])
            crAdjacencyList[routesDic['Commuter Rail'][route][i-1][0]].append(routesDic['Commuter Rail'][route][i])

#North Station and South Station got turned into North and South
#find all instances of South_CR or North_CR and store them
southStation=[x for x in crAdjacencyList if re.search('South_CR-.*',x)]
northStation=[x for x in crAdjacencyList if re.search('North_CR-.*',x)]

#Naively change the adjacency list such that all instances of North_CR are North Station_CR
for stop in crAdjacencyList:
    if stop in northStation:
        crAdjacencyList['North Station'+re.search('.*(-.*)',stop).group(1)]=crAdjacencyList[stop]
        del crAdjacencyList[stop]
    elif stop in southStation:
        crAdjacencyList['South Station'+re.search('.*(-.*)',stop).group(1)]=crAdjacencyList[stop]
        del crAdjacencyList[stop]
for stop in crAdjacencyList:
    for i in range(len(crAdjacencyList[stop])):
        if crAdjacencyList[stop][i][0] in northStation:
            crAdjacencyList[stop][i][0]='North Station'+re.search('.*(-.*)',stop).group(1)
        elif crAdjacencyList[stop][i][0] in southStation:
            crAdjacencyList[stop][i][0]='South Station'+re.search('.*(-.*)',stop).group(1)

# %%
#create a list of stops with lat, long data
subwayStopLoc={key[0]:key[1] for key in [y for x in subwayAdjacencyList.values() for y in x]}
busStopLoc={key[0]:key[1] for key in [y for x in busAdjacencyList.values() for y in x]}
crStopLoc={key[0]:key[1] for key in [y for x in crAdjacencyList.values() for y in x]}

# %%
def euclidean_distance(u,v):
    return np.sqrt((u[0]-v[0])**2+(u[1]-v[1])**2)

# %%
G=nx.Graph()
for stop in subwayStopLoc:
    G.add_node(stop,Subway=True,loc=subwayStopLoc[stop])
for stop in subwayAdjacencyList:
    for i in range(len(subwayAdjacencyList[stop])): 
        if G.has_edge(stop,subwayAdjacencyList[stop][i][0]) and 'Subway' in G[stop][subwayAdjacencyList[stop][i][0]]:
            continue
        else:
            G.add_edge(stop,subwayAdjacencyList[stop][i][0],Subway=True,Distance=euclidean_distance(subwayStopLoc[stop],subwayAdjacencyList[stop][i][1]))
for stop in busStopLoc:
    if stop in G:
        G.node[stop]['Bus']=True
    else:
        G.add_node(stop,Bus=True,loc=busStopLoc[stop])
for stop in busAdjacencyList:
    for i in range(len(busAdjacencyList[stop])):
        if G.has_edge(stop,busAdjacencyList[stop][i][0]) and 'Bus' in G[stop][busAdjacencyList[stop][i][0]]:
            continue
        else:
            G.add_edge(stop,busAdjacencyList[stop][i][0],Bus=True,Distance=euclidean_distance(busStopLoc[stop],busAdjacencyList[stop][i][1]))
for stop in crStopLoc:
    if stop in G:
        G.node[stop]['Commuter_Rail']=True
    else:
        G.add_node(stop,Commuter_Rail=True,loc=crStopLoc[stop])
for stop in crAdjacencyList:
        for i in range(len(crAdjacencyList[stop])):
            if G.has_edge(stop,crAdjacencyList[stop][i][0]) and 'Commuter_Rail' in G[stop][crAdjacencyList[stop][i][0]]:
                continue
            else:
                G.add_edge(stop,crAdjacencyList[stop][i][0],Commuter_Rail=True,Distance=euclidean_distance(crStopLoc[stop],crAdjacencyList[stop][i][1])) 

sameNodes={node:None for node in G.nodes()} #create a dictionary of keys as stops and vals set to None
nodes=list(sameNodes)#the copy of these nodes will be used as look up
for node in nodes:
    if node not in sameNodes:
        continue
    isoNodes=[x for x in G.nodes() if (x!=node and (G.node[x]['loc'] == G.node[node]['loc'] or (euclidean_distance(G.node[x]['loc'],G.node[node]['loc'])<0.0008 and str(x).split('_')[0]==str(node).split('_')[0])))]#created a list isoNodes to find nodes wit the same location that aren't the same.
    for isonode in isoNodes:
        del sameNodes[isonode]#delete the instance of this stop because we already accounted for it
    sameNodes[node]=isoNodes

sameNodes={x:sameNodes[x] for x in sameNodes if len(sameNodes[x])>0}

for node in sameNodes:
    for node_1 in sameNodes[node]:
        try:
            G=nx.contracted_nodes(G,node,node_1)#contract the nodes s.t. these two nodes are now one
        except:
            print(node,node_1)



sub_stop_list = []
bus_stop_list = []
cr_stop_list=[]

for node in G.nodes():
    if 'Subway' in G.node[node]:
        sub_stop_list.append(node)
    elif 'Bus' in G.node[node]:
        bus_stop_list.append(node)
    elif 'Commuter_Rail' in G.node[node]:
        cr_stop_list.append(node)

for stop_sub in sub_stop_list:
    for stop_bus in bus_stop_list:
        if euclidean_distance(G.node[stop_sub]['loc'],G.node[stop_bus]['loc'])<0.003:
            G.add_edge(stop_sub,stop_bus,Walk=True,Distance=euclidean_distance(G.node[stop_sub]['loc'],G.node[stop_bus]['loc']))
    for stop_cr in cr_stop_list:
            if euclidean_distance(G.node[stop_sub]['loc'],G.node[stop_cr]['loc'])<0.003:
                G.add_edge(stop_sub,stop_cr,Walk=True,Distance=euclidean_distance(G.node[stop_sub]['loc'],G.node[stop_cr]['loc']))

for stop_cr in cr_stop_list:
    for stop_bus in bus_stop_list:
        if euclidean_distance(G.node[stop_cr]['loc'],G.node[stop_bus]['loc'])<0.003:
            G.add_edge(stop_cr,stop_bus,Walk=True,Distance=euclidean_distance(G.node[stop_cr]['loc'],G.node[stop_bus]['loc']))


G.remove_edges_from(G.nodes_with_selfloops())

nx.write_gpickle(G, "MBTA.gpickle")

# %%
#creates the subway layer of the MBTA
subwayGraph=nx.Graph()
for stop in subwayStopLoc:
    subwayGraph.add_node(stop,Subway=True,loc=subwayStopLoc[stop])
for stop in subwayAdjacencyList:
    for i in range(len(subwayAdjacencyList[stop])): 
            subwayGraph.add_edge(stop,subwayAdjacencyList[stop][i][0],Distance=euclidean_distance(subwayStopLoc[stop],subwayAdjacencyList[stop][i][1]))

sameNodesSub={node:None for node in subwayGraph.nodes()}
nodesSub=list(sameNodesSub)
for node in nodesSub:
    if node not in sameNodesSub:
        continue
    isoNodes=[x for x in subwayGraph.nodes() if x!=node and subwayGraph.nodes()[x]['loc']==subwayGraph.nodes()[node]['loc']]
    for isonode in isoNodes:
        del sameNodesSub[isonode]
    sameNodesSub[node]=isoNodes  

sameNodesSub={x:sameNodesSub[x] for x in sameNodesSub if len(sameNodesSub[x])>0}
for node in sameNodesSub:
    for node_1 in sameNodesSub[node]:
        try:
            subwayGraph=nx.contracted_nodes(subwayGraph,node,node_1)
        except:
            print(node,node_1)
            
subwayGraph.remove_edges_from(list(nx.selfloop_edges(subwayGraph)))
nx.write_gpickle(subwayGraph, "MBTA_Rapid_Transit.gpickle")

# %%
#creates the bus layer of the MBTA
busGraph=nx.Graph()
for stop in busStopLoc:
    busGraph.add_node(stop,Bus=True,loc=busStopLoc[stop])
for stop in busAdjacencyList:
    for i in range(len(busAdjacencyList[stop])):
        busGraph.add_edge(stop,busAdjacencyList[stop][i][0],Bus=True,Distance=euclidean_distance(busStopLoc[stop],busAdjacencyList[stop][i][1]))

sameNodesBus={node:None for node in busGraph.nodes()}
nodesBus=list(sameNodesBus)
for node in nodesBus:
    if node not in sameNodesBus:
        continue
    isoNodes=[x for x in busGraph.nodes() if x!=node and busGraph.nodes()[x]['loc']==busGraph.nodes()[node]['loc']]
    for isonode in isoNodes:
        del sameNodesBus[isonode]
    sameNodesBus[node]=isoNodes  

sameNodesBus={x:sameNodesBus[x] for x in sameNodesBus if len(sameNodesBus[x])>0}
for node in sameNodesBus:
    for node_1 in sameNodesBus[node]:
        try:
            busGraph=nx.contracted_nodes(busGraph,node,node_1)
        except:
            print(node,node_1)
            
busGraph.remove_edges_from(list(nx.selfloop_edges(busGraph)))
nx.write_gpickle(busGraph, "MBTA_Bus.gpickle")

# %%
#creates the commuter rail layer of the MBTA
crGraph=nx.Graph()
for stop in crStopLoc:
    crGraph.add_node(stop,Commuter_Rail=True,loc=crStopLoc[stop])
for stop in crAdjacencyList:
        for i in range(len(crAdjacencyList[stop])):
            crGraph.add_edge(stop,crAdjacencyList[stop][i][0],Commuter_Rail=True,Distance=euclidean_distance(crStopLoc[stop],crAdjacencyList[stop][i][1]))
sameNodesCR={node:None for node in crGraph.nodes()}
nodesCR=list(sameNodesCR)
for node in nodesCR:
    if node not in sameNodesCR:
        continue
    isoNodes=[x for x in crGraph.nodes() if x!=node and crGraph.nodes()[x]['loc']==crGraph.nodes()[node]['loc']]
    for isonode in isoNodes:
        del sameNodesCR[isonode]
    sameNodesCR[node]=isoNodes  

sameNodesCR={x:sameNodesCR[x] for x in sameNodesCR if len(sameNodesCR[x])>0}
for node in sameNodesCR:
    for node_1 in sameNodesCR[node]:
        try:
            crGraph=nx.contracted_nodes(crGraph,node,node_1)
        except:
            print(node,node_1)
crGraph.remove_edges_from(list(nx.selfloop_edges(crGraph)))
nx.write_gpickle(crGraph, "MBTA_Commuter_Rail.gpickle")

# %%
def computeShortestPath(graph,u,v):
    if nx.has_path(graph,u,v):
        shortestPath=nx.shortest_path(graph,u,v)
        d=sum([euclidean_distance(graph.nodes()[shortestPath[i]]['loc'],graph.nodes()[shortestPath[i-1]]['loc']) for i in range(len(shortestPath)) if i!=0])
        return d
    else:
        return 1000
#computeShortestPath(G,'Kenmore_Green-B','Boston Univ East_Green-B')

#rough idea for creating walking distances
[x for x in G.nodes() if euclidean_distance(G.nodes()[x]['loc'],subwayGraph.nodes()['Packards Corner_Green-B']['loc'])<=0.003 and G.has_edge('Packards Corner_Green-B',x)==False and x!='Packards Corner_Green-B']
# Out:
# []

# %%
# Out:
# AtlasView({'1079 Commonwealth Ave_57': {'Bus': True, 'Distance': 0.0027150561688488338}, 'Brighton Ave @ Linden St_57': {'Bus': True, 'Distance': 0.0040916648200944343}})

# %%
#original network efficiency algorithm, to be discarded
def networkEfficiency2(graph):
    D_ij=0
    L_ij=0
    for node in graph.nodes():
        shortestPath=nx.shortest_path_length(graph,node,weight='Distance')
        d_ij=sum([shortestPath[x]**-1 for x in shortestPath if shortestPath[x]!=0])        
        l_ij=sum([euclidean_distance(graph.node()[node]['loc'],graph.node()[x]['loc'])**-1 for x in graph.nodes() if graph.node()[node]['loc']!=graph.node()[x]['loc']])
        D_ij+=d_ij
        L_ij+=l_ij
    return D_ij/L_ij

def networkEfficiency(graph):
    '''
    Calculate network efficiency of each node in a graph'''
    D_ij=0
    L_ij=0
    temp_1 = 0
    temp_2 = 0
    for node in graph.nodes():
        d_ij = 0
        shortestPaths=[x for x in nx.shortest_path(graph,node,weight='Distance').values() if len(x)>1]
        #develops tuples of adjacent edges in shortest path
        #so if shortest path is [a,b,c] then this creates [(a,b),(b,c)]
        shortestPaths=[list(zip(x[::1],x[1::1])) for x in shortestPaths]
        #sums the lengths of the euclidean distances of the shortest paths so sum([dist(a,b),dist(b,c)]).
        d_ij=sum(sum(graph.get_edge_data(y[0],y[1])['Distance'] for y in x if graph.get_edge_data(y[0],y[1])['Distance']>0)**-1 for x in shortestPaths)
        l_ij=sum([euclidean_distance(graph.node[node]['loc'],graph.node[x]['loc'])**-1 for x in graph.nodes() if graph.node[node]['loc']!=graph.node[x]['loc']])
        graph.node[node]['Efficiency'] = d_ij/l_ij
        D_ij+=d_ij
        L_ij+=l_ij
    return D_ij/L_ij, graph


e, G_1 = networkEfficiency(G)

# %%
e
# Out:
# 0.70694914741641646

# %%
from collections import OrderedDict
#second_dict = nx.shortest_path(G_1,'Downtown Crossing_Orange').keys()
#first_dict = G.nodes()

#diff = set(first_dict) - set(second_dict)
#diff
#print(G_1.node['Tremont St @ Winter St_Red'])
#print(G_1.node['Park Street'])
print (e)
nx.write_gpickle(G_1, "MBTA_eff_best.gpickle")
d = nx.get_node_attributes(G_1,'Efficiency')
d_descending = OrderedDict(sorted(d.items(),key=lambda kv: kv[1], reverse=True))
for x in d_descending:
    #try:
    #    k = G.node[x]['Subway']
    print (str(x) + ' ' + str(d_descending[x]))
    #except:
    #    continue
# Out:
# 0.706949147416
# Washington St @ Dean St_34E 0.953447019932
# Washington St @ Marshall St_34E 0.948741351063
# Opp 20 Washington St_34E 0.941206128081
# Washington St opp Waldo Way_34E 0.931035285317
# Washington St @ Canton Center_716 0.919366358788
# Canton Center_CR-Providence 0.918244901136
# Xaverian Brothers HS_34E 0.911866022889
# Dudley_19 0.90099323091
# Middleborough/Lakeville_CR-Middleborough 0.89796273028
# Washington St @ Hooper St_34E 0.893466494698
# Washington St from Church St to High St (FLAG)_716 0.891792889463
# Central_Red 0.890806401462
# Main St opp South St_101 0.889680078315
# North Station_Orange 0.888625547654
# Government Center_Blue 0.888237391608
# North Station-Newburyport 0.88772729421
# Massachusetts Ave @ Albany St_1 0.886906086083
# State Street_Blue 0.886476456386
# Tremont St @ Winter St_Red 0.885698429383
# Haymarket_Green-B 0.885501112543
# Cambridge St @ Center Plaza_39 0.885016859797
# Washington St from High St to Cobbs Corner (FLAG)_716 0.883952330412
# Park Street 0.883699321901
# Congress St @ North St_4 0.883483010232
# Tremont St @ Beacon St_39 0.882693703528
# Montello_CR-Middleborough 0.881557966915
# Downtown Crossing_Orange 0.881366374749
# Montello Commuter Rail_230 0.880543375971
# Sullivan Square_Orange 0.879767321311
# Cobbs Corner, Canton_716 0.879503243147
# Congress St @ Haymarket Sta_4 0.87911153929
# Mystic Ave @ Union St_95 0.877907332653
# Worcester_CR-Worcester 0.877841079277
# Congress St @ State St_4 0.877340282476
# Bridgewater_CR-Middleborough 0.87682735522
# Main St @ Dorrance St_101 0.87621455045
# Mansfield_CR-Providence 0.872616334859
# Washington St @ Croft Regis Rd_34E 0.872506791598
# South Station_Red 0.870847771381
# South Station-Foxboro 0.870553478894
# Grafton_CR-Worcester 0.867514574479
# New Sudbury @ Congress St_352 0.866684169762
# Tremont St opp Temple Pl_15 0.866145590748
# Temple Pl @ Washington St_749 0.866099269192
# Summer St @ South_11 0.865664019786
# Porter_Red 0.865049404316
# Campello_CR-Middleborough 0.864564745926
# Westborough_CR-Worcester 0.864022061299
# Porter Square_CR-Fitchburg 0.863851327061
# 37 Riverside Ave @ Medford Sq_101 0.863810549247
# Newmarket_CR-Fairmount 0.863319537855
# Otis St @ Summer St_7 0.86268411557
# Copley_Green-B 0.861408929196
# Newmarket St @ Massachusetts Ave_10 0.861303180997
# Prospect St @ Bishop Allen Dr_91 0.86130147308
# Tremont St @ Boylston_15 0.861246432133
# Boylston St @ Dartmouth St_9 0.860814353661
# 83 Washington St opp Ellis Ave_34E 0.860061884503
# N Washington St @ Thacher St_8993 0.859019450869
# Bedford St @ Chauncy St_7 0.858427995271
# Ruggles_Orange 0.85783034961
# Uphams Corner_CR-Fairmount 0.857817653968
# Green St @ Pearl St_47 0.857427530842
# Harvard_Red 0.857225797597
# Kingston_CR-Kingston 0.857104745891
# 169 Washington St opp Neponset St_34E 0.856849133666
# Brockton_CR-Middleborough 0.856173595448
# Boylston_Green-B 0.855993391857
# Massachusetts Ave @ Prospect St_1 0.855866490078
# Massachusetts Ave @ Sidney St_701 0.855523683135
# Halifax_CR-Kingston 0.855100990842
# Huntington Ave @ Fenwood Rd_39 0.854418498562
# Fenwood Road_Green-E 0.854280212957
# 77 Massachusetts Ave_1 0.853267956585
# Essex St @ Atlantic Ave_751 0.853211504197
# Andrew_Red 0.853097918852
# Hanson_CR-Kingston 0.851660847901
# Washington St @ Gay St_34E 0.851343522126
# Fitchburg_CR-Fitchburg 0.850914101394
# Hancock St @ Wentworth Rd_201 0.850901233624
# Clippership Dr @ Riverside Towers_101 0.850624058649
# Roxbury Crossing_Orange 0.850454709156
# Dudley St @ Warren St_41 0.850213691271
# Broadway_Red 0.849776980864
# Cambridge St @ Saltonstall Bldg_39 0.849405514923
# Mystic Ave @ James St_95 0.84902646335
# Pearl St @ Congress St_4 0.848700864102
# Massachusetts Ave @ Pearl St_64 0.848216496756
# Washington St_716 0.848015862524
# Chinatown_Orange 0.847584788959
# Tufts Medical Center_Orange 0.846129176173
# Tremont St opp Roxbury Crossing Sta_66 0.846035777575
# Massachusetts Ave @ Holyoke St_1 0.845827460541
# Forest Hills_Orange 0.845150793376
# Plymouth_CR-Kingston 0.844776276613
# Elm Ave @ Hancock St_212 0.844750394689
# North Leominster_CR-Fitchburg 0.844441625099
# Massachusetts Ave @ Shirley St_10 0.844321155138
# Prospect St @ Harvard St_64 0.844153223207
# Bowdoin_Blue 0.844055852932
# Summer St @ Dorchester Ave_4 0.843718532875
# Aquarium_Blue 0.843655389208
# Cambridge St @ Carter St_86 0.843177402621
# N Washington St @ Commercial St_111 0.843112249953
# Washington St @ Melnea Cass Blvd_749 0.843003857264
# Wachusett_CR-Fitchburg 0.842968237085
# Malcolm X Blvd @ Shawmut Ave_41 0.842183566254
# 757 Hancock St_202 0.841880826403
# Mattapan_Mattapan 0.841834891176
# Massachusetts Ave @ Memorial Dr_1 0.841740155743
# Western Ave @ Green St_64 0.841146070628
# Southborough_CR-Worcester 0.841057144652
# 529 Main St_8993 0.840263804955
# Washington St @ Chickering Rd_34E 0.840204413894
# Atlantic Ave @ State St-Marriott Hotel_4 0.839535052431
# Stuart St @ Tremont St_553 0.839316672063
# Hynes_Green-B 0.839252837388
# 160 Main St_96 0.839153380215
# Washington St opp Hill St_34E 0.837098319181
# Ruggles St @ Shawmut Ave_19 0.836917369976
# Sharon_CR-Providence 0.83685678005
# Brookline St @ Green St_47 0.836747770698
# Cambridge St @ Bowdoin St_57 0.836670821362
# Park St @ Dorchester Ave_19 0.836504896404
# Massachusetts Ave @ Bigelow St_1 0.836355945758
# Washington St @ Lenox St_10 0.835554318888
# Waltham_CR-Fitchburg 0.835407303473
# Melnea Cass Blvd @ Washington St_708 0.834922634969
# Hancock St opp Butler Rd_211 0.834824028177
# Ashland_CR-Worcester 0.834537110491
# Hancock St @ Furnace Brook Pkwy_210 0.834486626218
# Ayer_CR-Fitchburg 0.834456172333
# Riverway_Green-E 0.83439644667
# Shirley_CR-Fitchburg 0.833762939518
# Medford Sq @ City Hall Parking lot_134 0.833379765728
# Albany St opp Randall St_1 0.833065503235
# Museum of Fine Arts_Green-E 0.832514957253
# Whitman_CR-Kingston 0.832444445593
# Fields Corner_Red 0.832196616142
# Atlantic Ave. @ Congress St._4 0.83209770771
# Hancock St opp Merrymount Rd_211 0.831962210926
# Hancock St @ Clay St_201 0.831499220538
# Elm Ave opp Greene St_211 0.831384153671
# Upland Woods_34E 0.830828298698
# Four Corners/Geneva_CR-Fairmount 0.830680129692
# South Bay Mall @ Stop and Shop_16 0.830673318712
# Jackson Square_Orange 0.830498211918
# Massachusetts Ave @ Island St_10 0.830469292518
# Hancock St @ Carruth St_202 0.83034443974
# Dudley St @ Shawmut Ave_14 0.830288968641
# Central Avenue_Mattapan 0.830068522438
# Columbia Rd @ Holden St_17 0.829740032066
# Central Ave @ Central Ave_240 0.828977840596
# Huntington Ave @ Louis Prang St_39 0.828919357835
# JFK/UMASS_Red-Ashmont 0.828847083643
# Ruggles St @ Huntington Ave_708 0.828391898555
# Brandeis/Roberts_CR-Fitchburg 0.82770544464
# Hancock St opp Greenleaf St_210 0.827654406832
# Southampton St @ Newmarket St_10 0.827647226259
# Milton_Mattapan 0.827461391766
# Melnea Cass Blvd @ Harrison Ave_171 0.827398768914
# Quincy Center_Red 0.826921218955
# Winthrop St @ Medford HS_134 0.82637142845
# Devonshire St @ Milk St_92 0.825276523097
# South St @ Turner St_553 0.825252389273
# Washington St @ George St_34E 0.82503483607
# Somerville Ave @ White St (Porter Sq)_83 0.824901133944
# Washington St @ Granite St_34E 0.824503715336
# Massachusetts Avenue_Orange 0.824267566642
# Massachusetts Ave @ St Botolph St_1 0.824207050629
# Massachusetts Ave @ NStar_16 0.824175644274
# Hancock St @ Quincy Center_Red 0.824157829662
# W Broadway @ A St_11 0.823942399131
# Boston St opp Washburn St_16 0.823935247822
# Hancock St @ Saint Anns Rd_202 0.823636153137
# S Huntington Ave @ Huntington Ave_35 0.823494198202
# Dudley St @ Greenville St_15 0.823360875814
# Washington St @ School St_34E 0.822986129574
# Blue Hill Ave from Barbara Ln to Curry Coll (FLAG)_716 0.82294440605
# Canton Junction_CR-Providence 0.822403263052
# Adams St @ Eliot St_217 0.822357853703
# Boston St @ W Howell St_16 0.822203876309
# Dorchester Ave @ Gallivan Blvd_15 0.821874904075
# Salem St opp River St_95 0.821857758111
# 285 Tremont St_15 0.821829460812
# Centre St @ Linwood St_14 0.821181655737
# Chelsea St @ Fifth St_8993 0.8210190269
# Elm Ave @ Marlboro St_211 0.820949736193
# Atlantic Ave @ Seaport Blvd._4 0.820947389877
# Boston St opp Harvest St_16 0.820928920382
# 91 E Concord St_701 0.820311158464
# Centre St @ Cedar St_41 0.820248339194
# Prudential_Green-E 0.820237829347
# Washington St @ Inner Belt Rd_86 0.820190430362
# Boston St @ Ellery St_16 0.819621660845
# Winthrop St opp Smith Ln_326 0.819165157836
# Massachusetts Ave opp Clapp St_16 0.819150228341
# Ruggles St opp Kerr Way_19 0.818932394643
# Boylston St @ Massachusetts Ave_55 0.818830141613
# Columbia Rd @ Dudley St_16 0.818672350361
# Fifth St @ Chelsea St_93 0.818528104111
# 88 E Newton St_701 0.818215034806
# Boston St opp Mayhew St_17 0.817309123499
# Abington_CR-Kingston 0.817294104191
# Western Ave @ Kinnaird St_70 0.817001976852
# Hancock St @ Beale St_202 0.816888890237
# Brookline Ave @ Pearl St_60 0.816792011618
# Symphony_Green-E 0.816750868188
# Massachusetts Ave @ Hancock St_1 0.816724428793
# Washington St @ Williams St_47 0.81669582968
# Dorchester Ave @ Washington St_217 0.816626030712
# Atlantic Ave @ Milk St_4 0.816513233825
# Ruggles St @ Cabot St_19 0.816403739493
# 116 Riverside Ave_134 0.816232112236
# West Medford_CR-Haverhill 0.815570376657
# Seaver St opp Humboldt Ave_32 0.815366076683
# Atlantic Ave @ Commercial Wharf_4 0.815332610194
# Stuart St @ Charles St S_39 0.81529302303
# Holbrook/Randolph_CR-Middleborough 0.81523328589
# Blue Hill Ave @ Angell St_22 0.814965419122
# Blue Hills Pkwy @ River St_28 0.814717880018
# Brookline Village_Green-D 0.814491259317
# Ashmont_Mattapan 0.814422625042
# Ruggles St @ Annunciation Rd_9 0.814299106735
# Elm Ave @ Willow St_212 0.81427604911
# Washington St opp Holiday Inn_34E 0.814267713803
# Massachusetts Ave @ Peirson St_10 0.814177726565
# Magazine St @ Green St_83 0.813997343155
# Mission Park_Green-E 0.813621420223
# Humboldt Ave @ Seaver St_32 0.813510385672
# Alford St @ Main St_104 0.813470941238
# Hancock St @ Bird St_17 0.813444609755
# Curry College_716 0.813295731357
# Mystic Ave @ Reardon Rd_95 0.813260425107
# Adams St @ Canton Ave_217 0.813149843752
# Massachusetts Ave @ Johnston Gate_66 0.813058244837
# Dudley St @ Adams St_15 0.813011794445
# Lynn_CR-Newburyport 0.813003845277
# Washington St @ Walnut St_556 0.812841887259
# Melnea Cass Blvd @ Kerr Way_47 0.812593203997
# Davis_Red 0.812545384288
# 713 Winthrop St opp Robinson Rd_134 0.812480634439
# Dudley St @ Dearborn St_41 0.812427484442
# Boston Univ East_Green-B 0.812349686546
# Framingham_CR-Worcester 0.812323822171
# Harvard Sq @ Garden St_66 0.812260782758
# Franklin St @ Water St_230 0.812229651162
# Hancock St @ Woodbine St_Red 0.812159801483
# N Shore Rd @ Agawam St_411 0.812141708878
# Washington St @ Railroad Ave_34E 0.812100241756
# Norwood Depot_CR-Franklin 0.811926309485
# Boylston St @ Saint Cecilia St_170 0.811903775931
# Washington St @ Bartlett St_42 0.811872870975
# Green St @ Magazine St_64 0.811757369551
# Billings Rd @ W Elm Ave_211 0.81158992884
# Commonwealth Ave @ Granby St_57 0.811518674556
# Newtonville_CR-Worcester 0.81136336312
# A St @ Necco St_11 0.811315218116
# Belgrade Ave @ Robert St_35 0.811237956632
# W Elm Ave opp Franklin Ave_212 0.811235012366
# Arlington_Green-B 0.811097493677
# Broadway @ Mt Vernon St_90 0.811075444887
# Forest St from Medford Sq to Webster St (FLAG)_710 0.810978733316
# Winthrop St @ Winford Way_134 0.810978718985
# North Quincy_Red 0.810941894511
# Walnut St @ Washington St_556 0.810852828573
# Massachusetts Ave @ Beacon St_701 0.81082193579
# Wonderland_Blue 0.81080741667
# Main St @ Town Way_134 0.81054919531
# Washington St @ Erie St_23 0.810525151918
# W Second St opp W Third St_11 0.810500569419
# A St @ Mt Washington Ave_11 0.810298076049
# City Hall Mall @ Salem St_101 0.810242985654
# Boston Univ Central_Green-B 0.810198255154
# 361 Washington St @ Aldaen Pk_34E 0.810015776766
# Ipswich St @ Boylston St_55 0.809576408436
# Blue Hill Ave opp Babson St_28 0.809572979845
# 835 Huntington Ave opp Parker Hill Ave_35 0.809359036591
# Dorchester Ave @ Melville Ave_15 0.809227681411
# W Elm Ave @ Staunton St_212 0.809167904924
# Massachusetts Ave @ Dana St_1 0.809019836952
# Adams St opp Alleyne St_245 0.808949947618
# Roslindale Village_CR-Needham 0.80890633996
# W Elm Ave @ Mason St_211 0.808874426269
# Cedar Grove_Mattapan 0.808775779053
# Surface Artery @ Kneeland St_554 0.808723588422
# Blue Hill Ave @ Mattapan Sq_28 0.80872012196
# Dorchester Ave @ Adams St_18 0.808536061472
# Reedsdale Rd @ Central Ave_245 0.808522973639
# Dorchester Ave @ Van Winkle St_21 0.808465509473
# Massachusetts Ave @ Davenport St_96 0.808329531077
# Holbrook/Randolph Comm Rail Sta_238 0.808304514459
# Massachusetts Ave @ Clearway St_170 0.808288380996
# Tremont St @ Columbus Ave_43 0.808146288279
# Washington St from Chapman St to Lewis St (FLAG)_716 0.808123627656
# Park Dr @ Mountfort St_47 0.808049796556
# Gallivan Blvd @ Hutchinson St_215 0.807663545894
# Warren St opp Kearsarge Ave_19 0.807565807108
# Arborway @ Washington St_21 0.807564804621
# Back of the Hill_Green-E 0.807513023104
# Massachusetts Ave @ Columbia Rd_16 0.807405558112
# Dorchester Ave @ Richmond St_15 0.807234523375
# Littleton/Rte 495_CR-Fitchburg 0.807198961516
# Back Bay_Orange 0.80694899813
# Commercial St @ Fleet St_4 0.806934421944
# Blue Hill Ave @ Harvard St_28 0.806894302737
# Warren St @ Winthrop St_92 0.806870615145
# 191 Geneva Ave_19 0.806862479713
# Main St @ Highland Ave_134 0.806853040461
# South Bay Mall @ Office Max_16 0.806818103027
# Maverick_Blue 0.806751420743
# Dorchester Ave @ St Gregory St_15 0.806651681947
# Moody St @ Carter St_170 0.806492902432
# Robert St @ Belgrade Ave_51 0.80647262626
# Brookline Ave @ Aspinwall Ave_60 0.806377818759
# 445 Washington St @ Worthington St._34E 0.806351696429
# Coddington St @ Washington St_214216 0.806271859328
# Malden_Orange 0.806158877892
# Commonwealth Ave @ St Marys St_57 0.806153741317
# Franklin St opp Pearl St_230 0.805959759184
# Prospect St @ Gardner Rd_91 0.805789774895
# Main St @ Baldwin St_92 0.805774907165
# 1621 Dorchester Ave opp Dix St_15 0.805730979104
# South Acton_CR-Fitchburg 0.805706409705
# 2165 Dorchester Ave_15 0.805678011742
# Saint James Ave @ Dartmouth St_553 0.805608140568
# Dudley St @ Clifton St_41 0.805351511978
# Broadway St @ Bartlett St_104 0.805346083936
# 42 Dudley St_44 0.805280800018
# George St @ Winthrop St_96 0.805023887247
# Massachusetts Ave @ Trowbridge St_1 0.804980229585
# Mystic Ave @ Union St_92 0.80472644428
# 525 Washington St opp Marion St_34E 0.804712516053
# Park Dr @ Beacon St_57 0.804589281481
# Centre St @ Gardner St_41 0.804397606275
# South Bay Mall @ Target_10 0.804314035393
# Boston Ave @ Winthrop St_80 0.804263678944
# Warren St @ Church St_92 0.804214797334
# Vine St @ Moulton St_8993 0.804207995107
# Morton St @ Greendale Rd_31 0.804154386078
# Hancock St @ Chester St_202 0.804036158767
# Washington St @ Pearl St_65 0.804005198809
# Readville_CR-Franklin 0.803971203351
# Brookline St @ Tudor St_47 0.803935839386
# 105 S Huntington Ave_35 0.80387871454
# Dorchester Ave @ Valley Rd_15 0.803845655326
# College Ave @ Highland Ave_89 0.803711285467
# Franklin Park Loop @ Zoo entrance_45 0.803690298759
# Federal St @ Franklin St_501 0.803404691146
# Tremont St @ Prentiss St_22 0.803095680412
# Western Ave @ Howard St_64 0.803094928204
# Huntington Ave @ Riverway_66 0.80307981447
# Washington St opp Harris St_34E 0.803076251354
# Blue Hill Ave from Curry Coll to Canton Ave (FLAG)_716 0.80288960597
# Washington St @ Richards St_34E 0.802881032594
# Winthrop St @ Brooks St_94 0.802771502638
# Franklin St @ Sidney St_64 0.802577231256
# Hancock St @ Bowdoin St_17 0.802557996953
# Opp 1904 Canton Ave @ Trailside Museum_716 0.802483611751
# Main St @ Everell Rd_134 0.802125336408
# Winthrop St @ Chester Ave_96 0.802090439727
# West Natick_CR-Worcester 0.801959906425
# Hancock St @ Trull St_15 0.801911807119
# Carter St @ Waltham Comm Rail Sta_170 0.801905417526
# Malcolm X Blvd @ Tremont St_66 0.801819208009
# 191 Adams St_217 0.801763434339
# Main St @ Oak St_92 0.801680324141
# Hyde Park Ave @ Railroad_32 0.801584370261
# Malcolm X Blvd @ O'Bryant HS_66 0.801374592506
# Malden Center_CR-Haverhill 0.801337718626
# Dartmouth St @ Back Bay Sta_170 0.801082456312
# Centre St @ Highland Ave_14 0.801051528323
# W Elm Ave @ Gould St_211 0.800958634686
# Huntington Ave @ Longwood Ave_35 0.80071453559
# Main St @ School St_92 0.800322113711
# Seaver St opp Elm Hill Ave_22 0.80024926573
# Chelsea St @ Constitution Rd_8993 0.800210323374
# Broadway @ Langdon St_104 0.800199007588
# Theo Glynn Way @ Newmarket Sq_171 0.80007460575
# Massachusetts Ave @ Columbus Ave_1 0.800037585498
# Community College_Orange 0.799954626387
# Chelsea St @ Warren St_8993 0.799943150146
# Ruggles St @ Parker St_47 0.799919891393
# Foxboro_CR-Foxboro 0.799871368833
# Warren St @ Dabney Pl_44 0.799765413983
# Park Dr @ Fenway Station_Green-D 0.799759657315
# Longwood Medical Area_Green-E 0.799723683268
# Blue Hill Ave @ Woodhaven St_28 0.799647767635
# Hancock St @ Linden St_201 0.799453675708
# Main St @ Walker St_92 0.799410504417
# Carter St opp Commuter Rail_558 0.799277876693
# 173 Alford St_104 0.799120557178
# Seaver St opp Maple St_22 0.799092380015
# Albany St @ E Dedham St_47 0.799035082719
# Washington St @ Worcester St_10 0.79896665796
# Quincy Adams_Red 0.798783031302
# River St @ Washington St_15 0.79857855316
# Columbia Rd @ Devon St_16 0.798438834223
# Tremont St @ Tobin Community Center_66 0.798387824822
# 3867 Washington St opp Tollgate Way_35 0.798325957478
# Main St @ Marshall Rd_134 0.79811713332
# Dorchester Ave @ Centre St_15 0.798048671138
# Boylston St @ Berkeley St_9 0.798031067386
# Mt Auburn St @ Story St_71 0.798024500443
# Washington St opp Ruggles St_1 0.797842870949
# Bowdoin St @ Tovar St_15 0.797806547596
# Brigham Circle_Green-E 0.797493297742
# Washington St @ Guild St_42 0.797486398914
# Dorchester St @ Vinton St_10 0.797477922077
# Blue Hill Ave @ Almont St_28 0.797465745191
# Granite Ave opp Hilltop St_215 0.797293176654
# Tremont St @ Charles St S_43 0.797228686049
# Franklin Park Zoo @ Entrance_45 0.797097941023
# N Shore Rd @ Revere St_411 0.79708625623
# Dudley St @ Alexander St_15 0.797054767637
# 317 Washington St @ Fulton St_34E 0.797048492365
# Capen Street_Mattapan 0.796855459321
# Blue Hill Ave @ American Legion Hwy_29 0.796834869907
# Broadway @ Dexter St_104 0.796714098937
# Blue Hills Pkwy @ Blue Hill Ave_245 0.796673850231
# Beale St @ Greenwood Ave_Red 0.796628291384
# Broadway @ Norfolk St_64 0.796591355273
# Heath Street_Green-E 0.796472676691
# N Shore Rd @ Avon St_411 0.796465224496
# Readville St @ W Milton St_3233 0.796441409463
# Blue Hills Pkwy @ Austin St_245 0.796427557882
# Huntington Ave @ Evans Way_39 0.796411236631
# Quincy St @ Broadway opp Fogg Museum_68 0.796277392872
# Broadway @ Thorndike St_104 0.796164597236
# Malcolm X Blvd opp O'Bryant HS_15 0.795974709566
# Washington St opp Myrtle St_747 0.795954843327
# Commercial St. opp. Hull St._4 0.795651791848
# Albany St @ Wareham St_47 0.795562767425
# Lynn Commuter Rail_439 0.795501643973
# Boston Ave @ Holton St_80 0.795446867327
# Massachusetts Ave @ Wendell St_77 0.795359451818
# Boylston St @ Clarendon St_9 0.795319804275
# Wellington_100 0.795304761013
# Hilltop St @ Granite Ave_202 0.795151519048
# High St opp Governors Ave_94 0.795057180096
# Dorchester Ave opp Kemp St_18 0.794959147015
# Warren St @ Crawford St_14 0.794955402273
# Massachusetts Ave @ Exeter Park_77 0.7949531501
# Albany St @ Randolph St_47 0.794788864754
# River St @ Fremont St_15 0.794623665899
# JFK St @ Eliot St_66 0.794584748322
# 475 Winthrop St @ Temple Shalom_326 0.794579799715
# Main St @ Chestnut St_134 0.794510209592
# Independence Ave opp Verchild St_230 0.794474875823
# Washington St @ Cottage St_34E 0.794331970137
# Columbia Rd @ Seaver St_16 0.794230571533
# Laraway Rd @ Winchester Ctr_134 0.794142854739
# N Shore Rd @ Jackson St_411 0.794124861812
# Massachusetts Ave @ Albany St_10 0.794048802363
# Adams St @ Churchills Ln_217 0.794006928054
# Central Ave @ Brook Rd_240 0.793896553329
# Massachusetts Ave @ Magazine St_10 0.793813953741
# Wellington_Orange 0.79370691731
# Lowell_CR-Lowell 0.793488384074
# Malcolm X Blvd @ King St_19 0.79332412292
# Hancock St opp Albion Rd_201 0.793177649291
# Independence Ave opp Lurton St_230 0.793034390963
# Blue Hill Ave @ Mattapan St_28 0.793003529502
# Ipswich St @ Lansdowne St_55 0.792915646783
# Blue Hill Ave @ Goodale Rd_28 0.792792617402
# Bunker Hill St @ Baldwin St_8993 0.792652837738
# 16 Eliot St_86 0.792589361885
# Garden St opp Mason St_72 0.792543153956
# Humboldt Ave @ Hutchings St_32 0.792537077015
# Brookline St @ Erie St_47 0.792473785556
# Meridian St @ Havre St_120 0.792378676962
# Warren St @ Brunswick St_23 0.792221194261
# Washington St opp Dedham Plaza_34E 0.792213239547
# Gallivan Blvd opp Carruth St_215 0.792138344414
# Dalton St @ Boylston St_55 0.792122670121
# Boston Ave @ Harvard Ave_80 0.791983036699
# Union St @ Exchange St_439 0.7919480214
# Central Ave @ Maple St_240 0.791910244367
# River St @ Reservation Rd_33 0.791807966827
# Morton Street_CR-Fairmount 0.791593675877
# Hyde Park Ave opp Walk Hill St_32 0.79150400917
# Brookline Ave @ Francis St_60 0.791446194925
# Washington St @ Lochdale Rd_30 0.791432152217
# Centre St @ Bickford St_41 0.791418947883
# Blue Hill Ave @ Paxton St_28 0.791216751988
# Blue Hill Ave @ Wellington Hill St_28 0.791178315171
# Braintree_Red 0.791146560153
# Saint James Ave @ Clarendon St_39 0.79105676324
# Dorchester Ave @ Cheverus Rd_15 0.791050194713
# Main St @ Prospect St_134 0.790973793357
# South St @ Taft Hill Terr_14 0.790971494519
# Gallivan Blvd @ Adams St_215 0.790794213884
# Commercial St. @ Hanover St._4 0.790755088335
# Franklin_CR-Franklin 0.790592334343
# Holbrook Court Apartments_230 0.790571408441
# Elm St @ Saint James Ave_87 0.790265508517
# Broadway @ Felton St_68 0.790226047452
# Boston Ave @ Piggott Rd_80 0.790087799822
# Mountfort St @ Carlton St_47 0.789861628836
# Main St @ Hancock Ave_101 0.789845098147
# First Ave @ Terry Ring_93 0.789801065264
# Revere Beach_Blue 0.789794342328
# Main St @ Fairview Terr_134 0.789776496773
# Adams St @ Minot St_19 0.789723207407
# Tremont St @ Huntington Ave_66 0.789709703412
# Playstead Rd @ Irving St_95 0.789678200952
# College Ave @ Warner St_80 0.78964882569
# Broadway @ Inman St_68 0.78958131654
# Grove St @ Highland Ave_87 0.789269538363
# High St @ Allston St_94 0.789267371717
# Main St @ Vine St_134 0.789228298228
# High St @ Mystic St_326 0.789167929263
# 121 Bunker Hill St opp Lexington St_8993 0.789023156627
# Bunker Hill St @ St Martin St_8993 0.788831442391
# Washington St @ Archdale Rd_35 0.788779254012
# 618 N Main St opp Vesey Rd_240 0.78864810852
# Dudley St @ Belden St_41 0.788644182444
# Gallivan Blvd opp Huron Circle_215 0.78863639504
# Warren St @ Waumbeck St_22 0.788604704277
# Columbus Ave @ Dimock St_22 0.788555557392
# Terminal C_117 0.78853500977
# Talbot Avenue_CR-Fairmount 0.788510929441
# Prospect St @ Broadway_83 0.788413658996
# Washington St @ Mosgrove Ave_35 0.788403484634
# Beachmont_Blue 0.788230701338
# B St @ Silver St_11 0.788159024286
# 41 Independence Ave_230 0.788077507805
# Dorchester Ave @ Ellet St_18 0.788065484218
# Mt Vernon St @ South Point Dr_8 0.788052546548
# Royall St @ Compushare Driveway_716 0.788051834203
# River St @ Temple St_240 0.787939885194
# Talbot Ave @ Dorchester Ave_22 0.787805596639
# 372 Boston Ave opp Fairmount St_80 0.78779879595
# Washington St @ Incinerator Rd_34 0.787769373754
# Walnut Ave @ Circuit St_44 0.787746769924
# Blue Hill Ave @ Johnston Rd_28 0.787742434602
# Dorchester Ave @ Banton St_15 0.787732967636
# Opp 641 N Main St_240 0.787672072155
# Massachusetts Ave opp Waterhouse St_83 0.78751374144
# Blue Hill Ave @ Wayne St_45 0.787464141314
# Harrison Ave @ E Newton St_47 0.787448802587
# N Shore Rd @ York St_441 0.787425416708
# Broadway @ Prospect St_68 0.787315383843
# Riverside Ave @ Pleasant St_134 0.787142980072
# Blue Hill Ave @ Greenock St_28 0.78713966765
# Washington St @ E Berkeley St_15 0.786899117532
# Blue Hill Ave @ Seaver St_45 0.786867584027
# High St @ Wolcott St_94 0.786859596911
# Washington St @ Blue Hill Ave_19 0.786832443421
# Dorchester Ave opp Shepton St_15 0.786735079525
# Main St @ Bunker Hill St_92 0.78670632942
# Washington St opp Soper House Ln_230 0.786639864857
# Washington St opp Granfield Ave_35 0.786599051975
# Boylston St opp Gloucester St_170 0.786577018535
# Washington St @ Massachusetts Ave_170 0.786427951788
# Science Park_Green-B 0.786350170376
# Billings Rd @ Beach St_212 0.786296683402
# Dorchester Ave @ Talbot Ave_18 0.786118178363
# Kenmore_Green-B 0.786101134711
# Talbot Ave @ New England Ave_22 0.78608285737
# Washington St @ Holllis Ave_230 0.786039155881
# Bunker Hill St @ Polk St_8993 0.785987016246
# Talbot Ave opp Nightingale St_22 0.785979534312
# Garden St @ Concord Ave_72 0.785807667188
# North Beverly_CR-Newburyport 0.785757112737
# Granite Ave @ Milton St_202 0.785704675138
# Humboldt Ave @ Homestead St_32 0.785674761745
# River St @ Caton St_33 0.785619525891
# Bunker Hill St @ N Mead St_8993 0.785533207124
# High St @ Hillside Ave_134 0.785503206836
# Main St @ Lake St_134 0.785406290208
# Coddington St @ Quincy YMCA_214 0.785349214022
# Dorchester Ave opp Gibson St_15 0.785184356756
# Butler_Mattapan 0.78518155711
# Hyde Park Ave @ Wolcott Square_32 0.785071129838
# Huntington Ave @ Gainsborough St_39 0.784980032997
# Central Ave @ Rustlewood Rd_240 0.784849862885
# Columbia Rd @ Bird St_16 0.784804205075
# 775 Centre St_35 0.784775165058
# Playstead Rd @ Madison St_326 0.78475383221
# Washington St @ Jeremiah Burke HS_19 0.784700311426
# Columbia Rd opp Wyola Pl_16 0.784671557603
# Washington St @ South St_34E 0.784664541419
# N Shore Rd @ Oak Island St_411 0.784556899848
# River St @ Violante St_33 0.784411974176
# River St @ Alpine St_33 0.784280204417
# Columbia Rd @ Geneva Ave_16 0.78421316674
# Bunker Hill St @ Sackville St_8993 0.784152462973
# 245 Washington St_34E 0.784144108679
# Assembly_Orange 0.784086809531
# Adams St @ Dudley Lane_217 0.784032437245
# Natick Center_CR-Worcester 0.783901229107
# Washington St @ Foster St_214 0.78388625257
# 250 Dorchester Avenue_9 0.783767754762
# Bunker Hill St @ Pearl St_8993 0.783756998832
# Congress St @ Sleeper St_448 0.783615672838
# Reedsdale Rd @ Walnut St_245 0.783609189879
# Concord Ave @ Chauncy St_72 0.783546686189
# Pearl St @ Ivory Plaza_236 0.783495365928
# Beach St @ N Shore Rd_110 0.783434668651
# Reservation Rd @ River St_33 0.78338969458
# Washington St @ Sylvia Ln_34E 0.783289502815
# Belvidere St @ Huntington Ave_55 0.783199245525
# Boston Ave @ North St_80 0.783111868324
# Boston Ave @ Arlington St_80 0.783051637137
# Washington St @ Ruggles St_15 0.782968849619
# Broadway @ Austin St_101 0.782810610515
# Brook Rd @ Lincoln St_245 0.782781818768
# Columbia Rd opp Cushing Ave_15 0.782728138102
# Columbia Rd @ Blue Hill Ave_16 0.782626941589
# Blandford Street_Green-B 0.782617012698
# Washington St @ Cedar St_42 0.782588549565
# Tremont St @ Saint Alphonsus St_66 0.782586688785
# Bunker Hill St @ Medford St_8993 0.782549400635
# Elm St @ Cutter Ave_87 0.782545040436
# Washington St @ Pickett St_441 0.782491491383
# Brookline St @ Putnam Ave_47 0.782483768395
# High St @ Harvard Ave_94 0.782469163007
# Broadway @ Shurtleff St_116 0.78239383014
# Washington St opp River St_230 0.782325850769
# River St @ Gladeside Ave_15 0.782288504179
# Geneva Ave opp Olney St_19 0.782285917461
# Centre St @ Eliot St_35 0.782163891391
# Holmes St opp Moscow St_211 0.781979690755
# Washington St @ State St_441 0.781870078733
# Revere St @ Sagamore St_116 0.781848219189
# Boston Ave @ High St_80 0.781792865252
# Walpole St @ Elliot St_34E 0.781732866797
# Adams St @ Westmoreland St_19 0.781588149556
# Commonwealth Ave @ Silber Way_57 0.78156699443
# Gibson St @ Adams St_19 0.781457146349
# Independece Ave @ Centre St_230 0.781418063341
# Mt Auburn St @ Ash St_71 0.781348507741
# Broadway @ Gladstone St_104 0.781333699222
# Longwood Ave @ Binney St_47 0.781168732913
# Main St @ Elmwood St_105 0.781158811204
# Fields Corner Sta @ Geneva Ave_18 0.781155674348
# Granite St @ Hancock St_215 0.781093826432
# Washington St @ Elm St_230 0.780993601299
# Blue Hill Ave @ Morton St_28 0.780987008452
# Dorchester Ave @ Linden St_18 0.780963507954
# Brook Rd @ Reedsdale Rd_245 0.780898555364
# Hancock St @ Hancock Court_225 0.780874134579
# Washington St opp School St_230 0.780849269361
# 757 Main St_134 0.780829637557
# Opp 27 Washington St_441 0.780665808273
# Winchester Center_CR-Haverhill 0.780622774575
# Washington St @ Vassar St_23 0.780598169436
# Washington St @ Common St_230 0.780583102243
# Newport Ave @ Lincoln Ave_217 0.780550178082
# Central Ave @ Allerton Rd_240 0.780524372394
# Massachusetts Ave @ Bow St_1 0.780332755996
# Dorchester Ave @ Howell St_18 0.780322827266
# Mystic Ave @ Plaza Entrance_92 0.780283079692
# S Franklin St opp Quincy St_230 0.780280639005
# Columbus Ave @ New Cedar St_22 0.780242078826
# Independence Ave @ Federal Ave_230 0.780184511363
# Walnut Ave @ Rockland St_44 0.780142768345
# Newport Ave @ Newport Terr_217 0.780042112138
# Forge Park/495_CR-Franklin 0.780036873956
# Moody St @ Cushing St_556 0.779926864433
# Quincy Ave @ School St_225 0.779857999983
# Terminal B Stop 2_171 0.779769133309
# Brookline St @ Granite St_47 0.779709251315
# Columbus Ave @ Amory St_22 0.779552413258
# Broadway @ Fayette St_68 0.779538536725
# Broadway @ Columbia St_64 0.779521310698
# Western Ave @ Putnam Ave_64 0.779426223838
# Reedsdale Rd @ Canton Ave_245 0.779419566487
# Walnut St @ High St_60 0.779418232707
# W Broadway @ B St_9 0.779393678609
# Newport Ave @ Warren Ave_211 0.779385179038
# Elm St @ Hancock St_87 0.779354080708
# Newport Ave @ Beale St_Red 0.779136407155
# West Concord_CR-Fitchburg 0.779085481353
# S Franklin St @ Laurel Pk_230 0.779073871814
# Billings Rd @ Vassal St_212 0.779066714674
# Opp 250 Brook Rd_245 0.779003087803
# 196 Boston Ave opp Stoughton St_80 0.778992456427
# Washington St @ Montiquot Ave_230 0.77898196295
# 549 S Franklin St_230 0.778979415733
# Gallivan Blvd @ Oakridge St_26 0.778921178783
# Broadway @ Mason St_89 0.778909530271
# Blue Hill Ave opp Glenway St_14 0.778887963394
# Brook Rd opp Windsor Rd_245 0.778837099197
# Boston Ave @ Mystic Valley Pkwy_80 0.778795970825
# B St @ W 5th St_11 0.778758272883
# Lincoln Ave @ Cliftondale Sq_430 0.778692813137
# Washington St @ Harmony Hill Way_34E 0.778670052676
# Adams St @ Fontbonne Academy_217 0.778626133806
# Tremont St @ Burke St_43 0.778593539136
# Exchange St @ Broad St_439 0.778535328753
# S Franklin St @ King Rd_230 0.778512027465
# Washington St @ West St_230 0.778442323931
# W Broadway @ Linsky Barry Ct_9 0.778391417107
# E Squantum St @ Hancock St_211 0.778380209215
# Pleasant St @ Washington St_441 0.778348514892
# Dudley St @ Virginia St_15 0.778265484747
# River St opp Wachusett St_33 0.778209077219
# Congress St @ A St_448 0.778188845717
# South Weymouth_CR-Kingston 0.777868948412
# Dorchester St @ Old Colony Ave_10 0.77784349121
# Playstead Rd @ Chardon Rd_326 0.777830470329
# Massachusetts Ave @ Tremont St_1 0.77777474153
# 261 S Franklin St_230 0.777769086095
# Main St opp Richardson St_134 0.777693095257
# N Shore Rd opp Blanchard Ave_441 0.777650126635
# Brook Rd @ Saint Marys Rd_245 0.777575846428
# Washington St @ New Washington St_86 0.777502349716
# Columbia Rd @ Glendale St_16 0.777371063516
# Dorchester Ave @ Hecla St_18 0.777218073354
# Hyde Park_CR-Franklin 0.777185603929
# Broadway @ Warner St_80 0.777154472899
# Holbrook Ct @ Linwood St_230 0.777093086538
# School St @ Phipps St_215 0.777069765377
# 716 S Franklin St_230 0.776979226907
# 677 Huntington Ave_35 0.776918674065
# Broad St @ Newhall St_441 0.776796744123
# Concord Ave opp Craigie St_72 0.776763963552
# Belgrade Ave opp Pinehurst St_35 0.776388372248
# Gallivan Blvd @ Milton Ave_26 0.776277921629
# Newport Ave @ Hancock St_202 0.776258979536
# 34 Heath St opp Bromley St_14 0.776164171661
# S Huntington Ave opp VA Hospital_39 0.776149468375
# Humboldt Ave @ Crawford St_32 0.776105702427
# Lawrence Memorial Hospital_710 0.776064489913
# Centre St @ Pearl St_108 0.775888156304
# Newport Ave @ Oakland Ave_211 0.775753268937
# opp 182 Reedsdale Rd @ MIlton Hospital_245 0.775684107631
# S Franklin St @ Hillsdale Rd_230 0.775647608688
# Auckland St @ Dewar St_18 0.775604203491
# N Harvard St opp Harvard Stadium Gate 2_86 0.775592379397
# College Ave @ Dearborn Rd_80 0.775580535646
# N Shore Rd @ John Ave Ext_439 0.775565177671
# Boston Ave @ Tufts Garage_80 0.775431463971
# Hyde Park Ave @ Milton St_32 0.77542740806
# Preble St @ Vinton St_16 0.775351340765
# Independence Ave @ Lawry St_230 0.775293470082
# Main St @ Oakes St_105 0.77525102166
# Commonwealth Ave @ University Rd_747 0.775147372337
# Coddington St @ Southern Artery_214 0.775107075092
# School St opp Gay St_230 0.77487626385
# Harrison Ave @ Worcester Sq_708 0.774831405424
# Morton St @ Wildwood St_21 0.774749469654
# Washington St @ Academy St_230 0.774715723101
# Cummins Hwy @ Rosewood St_30 0.774714909456
# Washington St @ McGrath Hwy_220 0.774691306933
# Somerville Ave @ Beacon Terr_83 0.774649896339
# Geneva Ave @ Tonawanda St_19 0.774647873331
# River St @ Cedar St_15 0.774570879315
# Geneva Ave @ Columbia Rd_19 0.774448541965
# Enon St @ Super Stop + Shop_451 0.774443671731
# South St @ Spalding St_3738 0.774371975738
# Heath St @ Parker St_14 0.774355703527
# Talbot Ave @ Bernard St_22 0.774348907205
# Franklin St @ Presidents Ave_230 0.774259405272
# Washington St opp Brookley Rd_42 0.774220857419
# Newport Ave @ Heritage Dr_201 0.774093859388
# Dorchester Ave @ Dorset St_18 0.77406186636
# Washington St @ Oakland St_42 0.774036583898
# Washington St @ Sumner St_34E 0.774022359707
# Greenbush_CR-Greenbush 0.773813429562
# Washington St @ Hobart Ave_230 0.773779251698
# Dedham Mall @ Old Navy_52 0.77377773256
# 55 Sea St_214 0.773720062234
# College Ave @ Boston Ave_80 0.773693363236
# Main St @ Hancock St_101 0.773641301069
# Holland St @ Wallace St_87 0.773566344492
# Pleasant St @ Russell St_101 0.773560127708
# Moody St @ Pine St_505 0.773498117246
# Springfield St @ Houghton St_91 0.773439590402
# Morton St @ Norfolk St_21 0.773383971013
# 7 Franklin St @ Fire House_441 0.773349882266
# Elm St @ Chester St_89 0.773327000067
# S Franklin St @ Dresser Ave_230 0.773324477686
# Billings Rd @ Calumet St_212 0.773269466095
# 778 S Franklin St_230 0.773269064062
# Main St @ Green St_136 0.773197006194
# Union St @ Chestnut St_436 0.77310274077
# Commonwealth Ave @ Islington St_558 0.773101414404
# Jack Satter House @ Revere Beach Blvd_411 0.773074283972
# Suffolk Downs_Blue 0.773072469278
# Kendall/MIT_Red 0.773062670204
# Main St @ Centre St_106 0.773059989933
# Terminal B Stop 1_171 0.773004615604
# Salem St @ Fellsway Garage_325 0.772875189186
# Washington St @ Robinson Ave_230 0.772830273175
# High St @ Bradlee Rd_134 0.772755759337
# Broadway @ Packard Ave_8993 0.772450460917
# Commonwealth Ave @ Marriott_558 0.772394328804
# Lincoln Ave @ Charlotte Rd_426 0.772385331394
# Brookline Ave @ Park Dr_19 0.772258217178
# Neponset Ave @ Victory Rd_201 0.77225729611
# Lincoln Ave opp Kent St_430 0.772216609088
# Huntington Ave @ Belvidere St_9701 0.772126705305
# Columbus Ave @ Walnut Ave_44 0.772126597584
# Grand Union Blvd @ Foley St_90 0.772105771243
# Revere St @ Michael Della Russo Way_116 0.772100888991
# Broadway opp Trowbridge St_68 0.77209894534
# Bay St @ Auckland St_18 0.772088365838
# Broadway @ Curtis St_87 0.772025517292
# Union St @ Smith St_436 0.771881061641
# Yawkey_CR-Worcester 0.771835192796
# Talbot Ave opp Kerwin St_22 0.771811993126
# Playstead Rd @ Clewley Rd_326 0.771776869753
# N Main St @ Wales Ave_240 0.771766146337
# S Franklin St @ Walsh Rd_230 0.771762593662
# Brookline Ave opp Newbury St_19 0.771672954532
# Washington St opp Savoy St_15 0.771635694208
# N Main St @ West St_240 0.771628110624
# Adams St @ Helena Rd_19 0.771614649154
# Blue Hill Ave_716 0.771511017098
# Washington St @ Metropolitan Ave_50 0.771501172852
# N Main St opp Roel St_240 0.771497552119
# S Franklin St @ Howard Ave_230 0.771459194062
# Central Ave opp Griggs Ln_240 0.771435044057
# Salem St @ Hadley Pl_101 0.771345571434
# Dorchester Ave @ Hancock St_18 0.77129379262
# Commonwealth Ave opp Ash St_558 0.771289340493
# Stimson St @ Washington St_35 0.77125534809
# 307 N Main St_240 0.771241590062
# Wood Island_Blue 0.771179847078
# Hancock St @ Highland Ave_230 0.771168984425
# Holmes St @ Billings Rd_212 0.771140197278
# Gibson St @ Dorchester Ave_19 0.771085741547
# S Franklin St @ Hamilton Way_230 0.771084974297
# Neponset Ave @ King St_201 0.771031934787
# City Hall @ Broadway_111 0.770985608998
# Quincy St @ Harvard St_68 0.77098329605
# Newport Ave @ George Rd_211 0.77098212448
# 1010 Massachusetts Ave opp Magazine St_708 0.770967295581
# Downer Ave @ Broad Cove Rd_220 0.770962298724
# Fellsway W @ Fells Ave_100 0.770948204445
# 355 Hancock St_230 0.770863395289
# High St @ Pitcher Ave_80 0.77078381795
# Broadway @ Crescent Ave_111 0.770758712567
# N Main St @ Jasper Ln_240 0.770740780256
# Centre St @ Burroughs St_39 0.770719116478
# 1034 N Main St_240 0.770690653282
# Newport Ave @ Furnace Brook Pwky_211 0.770623186066
# N Main St @ Reed St_240 0.770577650436
# Independence Ave @ Goddard St_230 0.770481480714
# Columbus Ave @ Ritchie St_44 0.770427059444
# Springfield St @ Newton St_91 0.770384745871
# Broadway @ Walker St_8993 0.770272820814
# Talbot Ave @ Lithgow St_26 0.770215454313
# Heath St @ VA Hospital_14 0.770160495805
# Huntington Ave @ Forsyth Way_39 0.770124815038
# Lincoln St @ Thaxter St_220 0.770023127167
# Pleasant St @ Rockaway St_441 0.769937166217
# Charles/MGH_Red 0.769935193269
# Morton St @ Harvard St_21 0.769906902902
# Walnut Ave @ Humboldt Ave_44 0.769873406063
# E Squantum St @ Newbury Ave_217 0.769765952138
# 564 N Main St_240 0.769732756923
# Columbia Rd @ Quincy St_16 0.769704381824
# S Franklin St @ Adams St_230 0.769684464319
# Talbot Ave @ Welles Ave_22 0.769624195888
# Dorchester Ave @ Pearl St_18 0.769591077261
# Washington St @ Elm St_220 0.769543806452
# Savin Hill_Red 0.769503101326
# Pleasant St opp Anderson St_441 0.769451251486
# 1002 S Franklin St_230 0.769298180114
# Broadway @ Highland Ave_68 0.769275898811
# Main St opp Pleasant St_101 0.769268195269
# Centre St @ Highland St_14 0.769195851073
# River St @ Tileston St_33 0.769048451584
# Brookline Ave @ Longwood Ave_60 0.769046543873
# Bellevue_CR-Needham 0.769039854831
# Broadway @ Westminster Ave_8993 0.769010373992
# Main St opp Hemmingway St_134 0.768976374812
# 265 Hyde Park Ave opp Eldridge St_32 0.768914365939
# First Ave @ Ninth St_93 0.768883704761
# 106 Heath St opp Bickford Ave_14 0.76884467193
# S Franklin St @ Technical Park Dr_230 0.76882847105
# Dorchster Ave @ Howes St_18 0.768789836371
# Washington St @ Tobin Rd_35 0.768768359473
# N Main St @ Grove St_240 0.768707688182
# Dorchester Ave @ Mayfield St_18 0.768699393907
# Ave Louis Pasteur @ Longwood Ave_19 0.768681011297
# Hancock St @ Smith St_230 0.768652797218
# Orient Heights_Blue 0.768623976055
# Broadway @ Gerrish Ave_111 0.768572342884
# Union St @ W Green St_436 0.768531513519
# Adams St @ Foster Ln_215 0.768481279142
# Courthouse_741 0.768474076531
# Main St @ Winthrop St_105 0.768465276231
# Northeastern_Green-E 0.768446928511
# Massachusetts Ave @ Harrison Ave_701 0.768394297018
# Concord Ave @ Bond St_72 0.768340383175
# Union St @ Silsbee St_436 0.768303275735
# Broadway @ Indiana Ave_101 0.768270027066
# Pleasant St opp Bessom St_441 0.768122750276
# Washington St @ Durnell Ave_34 0.768104536611
# Dorchester Ave @ Thornley Rd_18 0.768006245982
# N Main St @ Depot St_240 0.767990577695
# Centre St @ Sunnyside St_41 0.767959445305
# Main St @ Stow St_170 0.767904072349
# Malcolm X Blvd opp Madison Park HS_15 0.76788874644
# Quincy Ave @ Water St_225 0.767869171265
# S Franklin St @ Chandler St_230 0.767868737589
# Thirteenth St @ Fifth Ave_93 0.767733437857
# Wesley St @ Lynn St_109 0.767653826523
# Columbia Rd @ Hamilton St_16 0.767614737453
# S Franklin St @ South St_230 0.7676060564
# Pleasant St @ Essex St_441 0.767595685821
# 321 Adams St_217 0.767504750546
# Granite Ave @ Gallivan Blvd_202 0.76748134175
# Malcolm X Blvd @ Madison Park HS_22 0.767410743636
# Washington St @ Harvard St_23 0.767389366723
# Billings Rd @ Royal St_212 0.767277720961
# Humboldt Ave @ Waumbeck St_32 0.767256280776
# Dorchester Ave @ Cottage St_18 0.767241870245
# South Rd @ Great Rd_62 0.767228542122
# Dewar St @ Dorchester Ave_18 0.767015267841
# Main St @ Grant St_556 0.766979888779
# Salem Commuter Rail_451 0.766939330336
# Washington St opp Hancock St_230 0.766886590399
# Hilltop St opp Crockett Ave._202 0.766826240141
# Summer St @ Clifton St_99 0.766791997444
# Beach St @ Hancock Rd_109 0.766755381504
# Riverside Ave @ Park St_134 0.766717781328
# Neponset Ave @ S Monroe Ter_201 0.766671830416
# Washington St @ Albano St_34 0.766564313223
# Massachusetts Ave opp Walden St_77 0.766543505221
# Main St @ Forest Ave_105 0.766433454411
# College Ave @ Broadway_89 0.766426066613
# South St @ Angleside Rd_553 0.766296981184
# Harrison Ave. opp Plympton St_8 0.766209209439
# Royall St @ Beacon Lane_716 0.766150382443
# South St @ St Rose St_39 0.766132876657
# Belgrade Ave opp Penfield St_35 0.766019897004
# Heath St opp Hayden St_14 0.765830115107
# S Franklin St opp Norfolk Rd_230 0.765728624145
# Salem St @ Grant Ave_95 0.765680983611
# Summer St @ Lincoln St_132 0.765564981949
# Main St @ Russell Rd_134 0.765438515867
# Chestnut Hill Avenue_Green-B 0.765416047759
# Central Ave @ Hinckley Rd_240 0.765270341231
# Coolidge Corner_Green-C 0.765141858729
# Main St @ Kendall/MIT_Red 0.765108613624
# Salem_CR-Newburyport 0.76509114694
# Central Ave @ Valley Rd_240 0.765021425255
# Washington St @ Edwards St_220 0.764970983228
# Humboldt Ave @ ML King Blvd_44 0.764970940385
# N Franklin St @ Union St_230 0.764956455232
# Broadway @ Windsor St_68 0.764951883848
# Commonwealth Ave @ University Rd_57 0.764825522614
# Dorchester Ave @ Mt Vernon St_18 0.76482494346
# Dorchester Ave @ Melvinside Ter_18 0.764819921591
# Norwood Central_CR-Franklin 0.76478880083
# Adams St @ Pilgrim Rd_217 0.764773509514
# Harrison Ave @ E Lenox St_47 0.764671811574
# Watertown St @ Chapel St_558 0.764646324316
# Adams St @ Mechanic St_215 0.764619420179
# Gordon Ave @ River St_50 0.764581024183
# Chestnut Hill Ave @ Commonwealth Ave_51 0.764555478561
# Billings Rd @ Freeman St_211 0.76453766258
# Union St @ Pinkham St_436 0.764473831352
# Derby St @ Lafayette St_455 0.76444127725
# Pleasant St @ Gerry St_441 0.764418114219
# Hancock St @ Washington St_230 0.764372836957
# B St @ W 6th St_11 0.764359768421
# Harrison Ave @ E Brookline St_8 0.764354883992
# Stony Brook_Orange 0.76435153586
# Centre St @ Myrtle St_35 0.764315569193
# Main St @ Charles St_136 0.76415666134
# Pleasant St @ Bubier Rd_441 0.764145040425
# Broadway @ Ellery St_68 0.764135588636
# Humboldt Ave @ Munroe St_44 0.764096905276
# Billings Rd @ Tyler St_212 0.764004635352
# opp 721 N Main St_240 0.763925421343
# Washington St @ Algonquin St_23 0.763875987178
# Main St @ Franklin St_136 0.763826576891
# Wollaston_Red 0.763825240316
# Saratoga St @ Saint Edward Rd_712 0.763730369263
# Sea St opp Overlook Rd_214 0.76366489144
# North Billerica_CR-Lowell 0.763605247779
# Brookline Ave opp Yawkey Way_19 0.763545588902
# Salem St @ Park St_101 0.763527823894
# 800 N Main St_240 0.763474403563
# S Main St opp Centre St_238 0.763336020675
# Blue Hill Ave opp Columbia Rd_14 0.763276688988
# Heath St @ Walden St_14 0.763251794319
# Cummins Hwy @ Bismark St_30 0.763239223427
# Neponset Valley Pkwy @ River St_33 0.763190648609
# Walley St @ Gladstone St_120 0.763108805567
# Hancock St opp Glover Ave_202 0.763096990839
# N Main St @ Warren St_240 0.762961202298
# Dodge St @ Enon St_451 0.762929277485
# Washington St @ Williams St_42 0.762892944927
# Belgrade Ave @ McGraw St_36 0.762863923936
# S Main St opp Woodlawn Rd_238 0.762814388109
# E Broadway @ M St_10 0.762759699833
# Humphrey St @ Bates Rd_442 0.762652377172
# Bowdoin St @ Hendry St_15 0.762525015039
# Readville St @ Como Rd_3233 0.762492544405
# Bridge St @ Osgood St_451 0.762457740888
# Lynn St @ Beach St_119 0.762388243765
# Humphrey St @ Shelton Rd_442 0.762348994466
# N Main St @ Intervale Terr_240 0.762345327548
# Humboldt Ave @ Townsend St_44 0.762285713954
# Chapel St @ Watertown St_558 0.762272973493
# Concord Ave opp Buckingham St_72 0.762233829653
# Olive St @ Fayette St_456 0.762203379392
# Pleasant St @ Fellsway E_101 0.76206368658
# Warren St @ Walnut Ave_14 0.761962388093
# Broadway @ Dickson St_87 0.761962373986
# Opp 683 N Main St_240 0.76187459678
# W Broadway @ D St_9 0.76187315704
# Main St @ Clarendon St_97 0.761853017567
# Broadway @ Leonard St_89 0.761797193242
# Newton St @ Concord Sq_91 0.761731378187
# Main St @ Nahant St_136 0.761712936881
# South Rd @ Railroad Ave_62 0.761620258424
# Washington St @ Park St_23 0.761593515202
# Point of Pines_441442 0.761587293028
# Tremont St @ Douglas Pk_43 0.761578115872
# Bridge St @ Cromwell St_451 0.761518473724
# Oxford St @ Washington St_429 0.761512961076
# N Main St @ Langley Rd_238 0.761433215474
# Norfolk_CR-Franklin 0.761420451892
# Concord_CR-Fitchburg 0.761360941228
# Freeport St @ Morrisey Blvd_201 0.76125888994
# Main St @ Exchange St_170 0.76117081455
# N Franklin St @ Noonans Lane_230 0.761154217133
# River St @ George St_33 0.761103200718
# Revere St @ Hawes St_116 0.761064180094
# Broadway @ High St_104 0.761032545605
# Springs Rd @ Hancock St_62 0.760975207187
# Pleasant St @ Devereux St_441 0.760968412399
# Sea St opp Samoset Ave_214 0.760876920527
# W Milton St @ Pine Ave_3233 0.760858277779
# Robertson St @ Quarry St_217 0.760840544267
# Harrison Ave @ Melnea Cass Blvd_47 0.760730245924
# Salem St @ Cutler Hwy_426 0.760557811996
# Hancock St @ Billings Rd_202 0.760475482228
# Newport Ave @ Lillian Rd_211 0.760410169675
# N Main St @ Gordon St_240 0.760322701838
# Saratoga St @ Teragram St_712 0.760304659621
# 349 Adams St_217 0.760271664139
# Farragut Rd opp E 2nd St_10 0.760162175379
# Billings Rd @ Lunt St_211 0.760159163375
# Washington St opp Gardner Rd_65 0.760141417606
# Central Ave @ Columbine Rd_240 0.760053626145
# Nahant St @ Tudor St_439 0.760018963459
# Santilli Circle_110 0.759999091256
# S Franklin St @ Upland St_230 0.759969333257
# Pleasant St @ Gale St_101 0.759966657421
# 27 Beach Rd_439 0.759966135816
# N Franklin St @ Linfield St_230 0.759940841503
# Humphrey St @ Puritan Rd_442 0.759924174916
# West Roxbury_CR-Needham 0.759895170679
# 701 S Main St_238 0.759787665211
# Main St @ Cranes Ct_134 0.759756734532
# River St @ Newcroft Circle_15 0.759729501984
# N Main St @ Royal St_240 0.759674433144
# N Main St @ Chestnut St_240 0.759662866125
# Auburndale_CR-Worcester 0.759644400072
# 227 Sea St_214 0.759582741391
# Harvard St @ Aspinwall Ave_66 0.759545695318
# Centre St @ Lochstead Ave_35 0.759466599205
# 80 Stimson St_35 0.75943324034
# Broadway @ Eleanor St_116 0.759424247858
# Main St @ Edgehill Rd_170 0.759420225047
# Morton St @ Blue Hill Ave_21 0.759395471888
# Humphrey St @ Alden Rd_442 0.759381578692
# Beacon St @ Dickinson St_83 0.759374031721
# Washington St @ Wheatland Ave_23 0.759358082326
# Main St @ Malone St_170 0.75934533374
# Main St @ Hammond St_553 0.759309477721
# Cabot St @ Franklin Pl_451 0.759271640754
# Old Colony Ave opp Gavin Way_16 0.759268085027
# N Franklin St @ Cedarcrest Rd_230 0.759229416094
# Washington St @ Fairbanks St_65 0.75917515331
# N Franklin St. @ Elm Ave_230 0.759165617151
# Broadway @ Parker St_116 0.759048437665
# Saratoga St @ Annavoy St_712 0.7590482396
# Broadway @ Green St_116 0.758952133212
# Washington Street_Green-B 0.758906537391
# Sea St @ Barbour Terr_214 0.758872793304
# Main St @ Fiske St_170 0.758860626227
# Wellesley Farms_CR-Worcester 0.758817634303
# 263 Mt Vernon St @ St Christopher's Church_8 0.758761097718
# Belgrade Ave @ Walworth St_36 0.758608028722
# Walnut St @ Austin St_59 0.758597455542
# Old Colony Ave @ Msgr O'Callaghan Way_5 0.758592543683
# Broadway @ Webster Ave_116 0.758471403213
# W 7th St @ B St_11 0.758447989086
# Harvard St opp Vernon St_66 0.758438531905
# Hancock St @ Hancock Ave_230 0.758437610929
# Hampshire St @ Cambridge St_83 0.758435729573
# High St opp Edgehill Rd_60 0.758362029531
# Cabot St opp Highland Ave_451 0.758343852323
# Neponset Ave @ Ashmont St_201 0.75825536693
# Broad St @ Nahant St_441 0.758254932862
# Washington St @ McGrath Hwy_747 0.758221149578
# Lincoln Ave @ Morton Ave_426 0.75816837798
# 47 N Main St_238 0.758109549844
# Main St @ Baldwin Ave_105 0.758067784007
# Holland St @ Paulina St_87 0.758052618119
# Centre St @ Aldworth St_35 0.758042000126
# Washington St @ Heron St_40 0.7578250899
# Bennington St @ Swift St_120 0.757824584817
# Hancock St @ Walter J Hannon Pkwy_215 0.757711793698
# Washington St @ Joy St_86 0.757700324152
# Wilmington_CR-Lowell 0.757693244454
# Washington St @ School St_65 0.757673857009
# Fairbanks Street_Green-C 0.75762207011
# E Broadway @ N St_10 0.757621704592
# Centre St @ Columbus Ave_41 0.757444767138
# Lincoln_CR-Fitchburg 0.757425945185
# Opp 352 Lafayette St_455 0.757425602218
# Brookline Ave @ Fullerton St_19 0.757415699883
# Main St @ Richardson St_136 0.757402181631
# Dorchester Ave @ Edison Green_18 0.75732915874
# Cummins Hwy @ Florence St_14 0.757326137168
# S Huntington Ave @ Bynner St_39 0.757316462502
# Sea St @ Moffat St_214 0.757314281581
# 250 Mt Vernon St @ Geiger Gibson Health Center_16 0.757304817385
# ...
# Hamilton/Wenham_CR-Newburyport 0.575348690094
# Forest St @ Doty St_554 0.575261833614
# Eastern Ave @ Harvest St_456 0.574487066132
# Cross St @ Ferry St_105 0.574335105287
# Eastern Ave @ Clark St_456 0.574170903512
# Holyoke St @ O'Callaghan Way_429 0.574033962251
# Parker St @ Stearns St_52 0.57400250698
# Commandants Way @ Williams St_112 0.573968041009
# Melrose Cedar Park_CR-Haverhill 0.573797733245
# Station St_220 0.573720626152
# Needham St opp Columbia Ave_59 0.573374997403
# Wiswall Rd @ Indian Ridge Rd_52 0.573177633226
# Herald St @ Tremont St_9 0.572742009136
# Walnut St opp Fairmount Ave_429 0.572587013094
# Dedham St @ Wiswall Rd_52 0.572387996758
# Eastern Ave @ Oakwood Ave_424 0.571371932873
# Garfield Ave @ Washington Ave_429 0.571022284198
# Wiswall Rd opp McCarthy Rd_52 0.570849344015
# Lexington St @ Russell St_354 0.570830263341
# Sea St @ Palmer St_216 0.570626369426
# Opp 85 Columbian St_225 0.570274169432
# 380 Trapelo Rd_554 0.570238995971
# Elm St @ Haskell Ave_110 0.569983075623
# Old Mass Ave @ Wood St_627 0.569763076206
# Baker St @ Lasell St_37 0.569503110836
# Highland Ave @ Waddel St_710 0.569439069044
# 1407 Washington St @ DPW Yard_34E 0.568892908373
# Washington St @ Lithgow St_26 0.568850564811
# Opp 41 Columbian St_225 0.568806577443
# Main St @ Adams Place_225 0.568796399354
# Central Ave @ Reservoir St_59 0.568769344799
# O'Callaghan Way @ Holyoke St_426 0.568632283427
# Opp 129 Howard St_225 0.56814256092
# Reedsdale Rd @ Randolph Ave_245 0.567412092768
# N Beacon St @ Cambridge St_64 0.567123639847
# Opp 62 Water St_435 0.566999609832
# Main St @ Bayley Terrace_225 0.566452534183
# Attleboro_CR-Providence 0.565851885463
# 294 Eastern Ave_424 0.565368402337
# Lynn St @ Rainbow Rd_435 0.565101541817
# Trapelo Rd opp Porter Rd_554 0.564958138321
# 375 Palmer St_214 0.564850285225
# Turtle Pond Pkwy @ Dedham Pkwy_40 0.564406697473
# Opp 617 Lexington St_170 0.564007578089
# Old Mass Ave @ Marrett Rd_627 0.563959040568
# Parker St @ Boylston St_52 0.563803634649
# Seaport Blvd @ World Trade Center Opp. Seaport Htl_4 0.563680840157
# Trapelo Rd @ Cherry Ln_554 0.563224151569
# Corey St @ LaGrange St_37 0.563221610327
# Dedham St opp Arnold Rd_52 0.562915499344
# Eastern Ave @ Sheldon St_424 0.562703278163
# Dawes Drive_351 0.562143543288
# Spruce St @ Second St_112 0.5619875544
# Essex St @ Roosevelt Rd_222 0.561618520543
# 494 Essex St_222 0.561392847649
# Dedham St @ Carlson Ave_52 0.561264533121
# 67 Washington St_34E 0.56116637664
# 9 Washington St_34E 0.560244780623
# Lebanon St @ Bratley St_106 0.560089603771
# Needham St opp Charlemont St_59 0.559891419848
# Western Ave @ Ida St_426 0.559548460431
# Dedham St @ Nahanton St_52 0.559543034847
# Dedham St opp Rosalie Rd_52 0.559458466529
# N Central @ Beale St_211 0.559311264208
# Dedham St opp Greenwood St_52 0.55906260641
# Parker St @ Parker Ave_52 0.559029437694
# 1375 Washington St opp Jacobs Rd_34E 0.558472961145
# Old Mass Ave opp Bonair Ave_627 0.558470026181
# Trapelo Rd opp Briarwood Rd_554 0.558378955565
# Middle St opp Rockaway Ave_225 0.558325625012
# Mystic Ave. opp. Harvard St._95 0.557314081935
# Norfolk St @ Capen St_26 0.557265348355
# Middle St opp Mediterranean Dr_225 0.557160239884
# Washington St @ Breck Ave_501 0.556933016056
# Lexington St @ River St_505 0.556521574252
# Opp 650 Main St_225 0.556131235134
# Washington Ave @ Reynolds Ave_112 0.556026747811
# Cabot St @ Roosevelt Ave_451 0.555906541312
# 49 N Franklin St_435 0.555751502035
# Forest St @ Gann Academy_554 0.55566896117
# Norfolk St. @ Stanton St. opp. #227_26 0.554721221258
# Needham St @ Jaconett Rd_59 0.554715479888
# Quincy Ave @ Quirk Chevrolet_225 0.554640785021
# Woodward St @ Boylston St_59 0.553745868738
# Mystic Ave opp Bonner Ave_95 0.553590727739
# Centre St @ Hyde St_52 0.553263098244
# 45 Spruce St_112 0.55217800786
# Waverley Oaks Rd @ Brookfield Rd_554 0.55217314935
# First Ave @ Lynnfield St_436 0.552036078688
# 390 Salem St_95 0.551613597158
# 561 Main St_225 0.551588078684
# Kings Hill Dr @ Nottingham Ct_429 0.551395137097
# Newland St @ Huckins Ave_211 0.551019326443
# Lynn St @ Coolidge Ave_435 0.55079794988
# Boston Landing_CR-Worcester 0.550167894178
# Cummins Hwy @ River St_30 0.549594444474
# Faneuil St opp Bothwell Rd_64 0.549493334355
# 460 Eastern Ave_424 0.549082438275
# Middle St @ Tara Dr_225 0.548981389584
# Cypress St @ Braeland Ave_52 0.548686957718
# Chestnut St @ Pennsylvania Ave_59 0.548666225834
# Kings Hill Dr @ Magner Rd_429 0.548497207764
# Cabot St opp Columbia Rd_451 0.548255513723
# Atlantic Ave_714 0.547824108124
# Brook Rd @ Otis St_245 0.546930035412
# Broad St @ Fairmount Ave_222 0.546690863939
# Chestnut St @ Elliot St_59 0.546604604693
# 326 Mystic Ave_95 0.546212173848
# 617 Broad St_222 0.545660034082
# Lake St opp Hardy Residences_170 0.545082367069
# Lake St @ Hardy Residences_70A 0.545037100575
# Arthur St @ Guest St_64 0.544925878476
# Summer St @ Drydock Ave_4 0.544673980991
# Dedham St opp Meadowbrook Rd_52 0.544218593743
# Newcomb Ave @ Edison St_429 0.543997485084
# Lovers Leap Ave @ Everett St_435 0.543541637267
# Franklin St. @ Western Ave_429 0.543350854762
# Centre St @ Cushing St_52 0.543308256242
# Opp 177 Main St @ New Pond Village_34E 0.542847302681
# Winchester St @ Rockland St_52 0.542698776058
# 181 Lexington St_558 0.541147795394
# Dedham Pkwy @ Georgetowne Dr_40 0.540711353686
# Middle St @ Circuit Ave._225 0.540472869973
# Guest St @ Life St_64 0.539426311773
# Walnut St opp Jefferson Ave_429 0.539296447795
# Brook Rd @ Pleasant St_245 0.539164036241
# O'Callaghan Way opp Walnut Pk_429 0.538807427564
# River St @ Cummings Hwy_33 0.538001120268
# Boylston St @ Tully St_60 0.537321231637
# Beaver St @ Linden St_554 0.536938187218
# Middle St opp Maple St_222 0.536803914389
# Oak St @ Chestnut St_59 0.535968553231
# Oak St @ Elliot St_59 0.534986178237
# Salem St @ Almont St_95 0.534814210027
# Union St @ Prospect Ave_240 0.534608157288
# Eastern Ave @ Lambert Ave_424 0.534431117012
# N Beacon St @ Life St_64 0.534334252356
# Dedham St opp Country Club Rd_52 0.534223425019
# Middle St @ Academy Ave_222 0.53410057598
# Margin St opp Roycroft Rd_465 0.533766345265
# Mystic Ave opp Billings Ave_95 0.533686520834
# Southern Artery @ South St_225 0.533453513769
# N Beacon St @ Birmingham Pkwy_64 0.533183196242
# Faneuil St @ Bigelow St_64 0.532933550649
# Broad St @ Hillcrest Rd_222 0.532809190122
# N Beacon St @ Vineland St_64 0.5322473672
# Wash Blvd Opp Hull Medical Ctr (FLAG)_714 0.531716359519
# Washington St @ Western Ave_435 0.531499993684
# Galivan Blvd @ Wilmington St_26 0.531452407059
# North St @ Highland St_465 0.530622382471
# Dedham Pkwy opp Georgetowne Dr_33 0.530394319442
# Nantasket Ave from Atlantic Ave to Park Ave (FLAG)_714 0.529961299461
# Lexington St @ Stanley Rd_70A 0.529839314781
# Faneuil St @ Oak Square_64 0.529507377129
# Lebanon St Loop_106 0.529462338065
# Sylvan St opp Kimball St_106 0.528968869664
# Birmingham Pkwy @ Soldiers Field Rd_64 0.528665132802
# Parker St @ Athelstane Rd_52 0.528540738326
# Garfield Rd @ Newcomb Ave_429 0.528326279109
# Needham St @ Oak St_59 0.527752208291
# Winchester St @ Needham St_52 0.527740808224
# Elliot St @ Columbia Ave_59 0.527644620661
# Mystic Ave @ Hancock St_95 0.527608040698
# Middle St @ Winter St._225 0.527045334409
# Hallet St @ Hilltop St_201 0.526284353789
# Pleasant St @ Lambert Ave_222 0.526098228818
# Salem St @ Court St_95 0.525418925199
# North St opp Cushing St_465 0.525302475727
# Shaw St @ Quintree Mall_225 0.52523399122
# 210 Nahanton St_52 0.524864965188
# Walnut St opp Sterling St_429 0.524524278157
# Water St @ S Liberty St_465 0.524360305075
# Elliot St @ Linden St_59 0.524217851667
# Elliot St @ Charles St_59 0.524090429007
# Newcomb Ave @ Jefferson Ave_429 0.524007554173
# Lebanon St @ Swains Pond Ave_106 0.523694571809
# Lynn St @ Mcarthur Rd_435 0.523215803792
# 601 Broad St opp Cain Ave_222 0.52274142044
# Essex St @ Beckford St_465 0.522401046835
# Mystic Ave @ Fulbright St_95 0.522377899385
# 980 Morton St opp Owen St_26 0.521930466633
# Highland Ave @ Hobart Ave_217 0.521702686277
# Broad St @ Shawmut St_222 0.521025468907
# 156 Oak St_59 0.520712955057
# Margin St opp Driscoll St_465 0.520491163818
# Gallivan Blvd @ opp Marsh St_201 0.519639845588
# Salem St @ Paris St_95 0.519303957379
# Hobart St @ Brooks St_64 0.517319672363
# N Harvard St @ Oxford St_66 0.517168012506
# Pleasant St @ Riley Ave_222 0.516977939474
# O'Callaghan Way @ Walnut St_429 0.516751493124
# N Beacon St @ Market St_64 0.516728154514
# Totten Pond Rd @ Third Ave_70A 0.516618019837
# Parker St @ Cypress St_52 0.516492390966
# High St @ Perry St_435 0.516447724899
# Lexington St opp Curve St_70A 0.516442866139
# Rockland House Rd_714 0.515472535793
# High St @ Gould St_435 0.514776520576
# Dedham Pkwy @ Turtle Pond Pkwy_33 0.514107359705
# Boston @ Ford St_435 0.514041511214
# Main St @ Moreland St_101 0.513427555854
# Main St @ Henry St_101 0.51306853968
# Pleasant St @ Granite Post Lane_222 0.513041405982
# Baker St @ Capital St_52 0.513034318455
# 176 Water St_465 0.512911025616
# Highland Ave @ Hobart St_211 0.512418445459
# Essex Ctr Dr @ Essex Green Dr_436 0.512212836983
# Park Ave from Rockland Cir to Nantasket Ave (FLAG)_714 0.511813290689
# Elliot St @ Cottage St_59 0.51173444643
# 1197 Washington St_222 0.511234428202
# Rockland Circle from Rockland House to Park (FLAG)_714 0.511127044849
# Margin St opp Margin St Ct_465 0.510803359299
# Essex St @ Broad St_222 0.510496490646
# Union St @ Howard St_240 0.510145614167
# 302 Turtle Pond Pkwy_33 0.510043364753
# Pleasant St @ Village Rd_222 0.508703046684
# Beaver St @ Waverley Oaks Rd_554 0.507901749454
# 519 Broad St opp Center St_222 0.507748219408
# Lexington St @ Rumford St_558 0.507638400792
# N Harvard St @ Empire St_66 0.506325892008
# Opp 677 Winchester St_52 0.50599880481
# 100 Mutton Lane_222 0.505042259465
# Winchester St @ Goddard St_52 0.504844384723
# Water St @ Riverside St_465 0.504043960961
# Hobart St @ Falkland St_64 0.503927276083
# Essex Ctr Dr opp Essex Green Dr_465 0.503921811681
# Essex St @ Harrington Circle_222 0.503562967606
# Lynn St opp Fairview Ave_435 0.503552171575
# Wash Blvd_714 0.501677403011
# Park Ave @ Park Circle_62 0.500863450009
# Broad St opp Broad St Place_222 0.500502403066
# 1297 Washington St opp. Morse St._34E 0.500481976044
# Edison St @ Walnut St_429 0.500040730889
# High St @ Hunt St_465 0.499389899092
# Water St opp Broad St_465 0.499355254637
# Faneuil St @ Donnybrook Rd_64 0.499303076959
# 851 Pleasant St_222 0.499083646881
# Water St @ Endicott St_465 0.496274647728
# Sylvan St @ Gibson St_106 0.494751271489
# Margin St @ Shore Ave N_465 0.494657167353
# Shaw St @ Dewey Rd_225 0.494263188067
# Warren St @ Moreland St_10 0.494125766028
# Wilson Ave @ Bowdoin St_211 0.493989184159
# Faneuil St @ Brooks St_64 0.493646499185
# Nantasket Ave from Wash Blvd to Water St (FLAG)_714 0.493505312402
# Main St @ Neponset View Terr_34E 0.492304973032
# Warren St @ Whiting St_10 0.491635489412
# Faneuil St opp Garfield School_64 0.491613575091
# Warren St @ Waverly St_10 0.491513077049
# Parker St @ Dedham St_52 0.490964684167
# Wilson Ave @ Belmont St_217 0.490903955391
# Walnut St opp Edison St_429 0.489757897239
# Faneuil St @ Brackett St_64 0.488426330261
# Wilson Ave @ Mascoma St_211 0.488367840743
# Shaw St opp Dewey Rd_225 0.487988112554
# 929 Washington St_34E 0.487656472042
# Broad St @ Pleasant St_222 0.486657282891
# Sylvan St @ Lebanon St_106 0.486188106013
# Pleasant St opp Sanderson Ave_222 0.485934410869
# Highland Ave @ Wilson Ave_217 0.485548886487
# Lebanon St @ Marshall Ave_106 0.485227785812
# Euclid Ave @ Broadway_435 0.484882955617
# Hayward St @ Heritage Ln_225 0.484259443176
# Quincy Ave @ W Howard St_225 0.48377645084
# Hull Medical Center (FLAG)_714 0.48373496274
# Parker St @ Parker Rd_52 0.483605000206
# Mutton Lane @ Old Stone Way_222 0.483545978326
# Broadway @ Broadway Circle_435 0.481907400904
# Broadway @ Euclid Ave_435 0.481803813611
# 44 Broadway_435 0.48135739893
# Lynn St @ Spring Pond Rd_435 0.480689309223
# Warren St @ Maywood St_10 0.480102774157
# Parker St @ Hagen Rd_52 0.48007587737
# Pleasant St @ Water St_222 0.478793240151
# Opp 680 Lexington St_70A 0.478516656553
# Mystic Ave @ Shore Dr_95 0.478231868819
# Nantasket Ave from Park Ave to Wash Blvd (FLAG)_714 0.477111062144
# Wilson Ave opp Mascoma St_217 0.476029113095
# High St opp Perry St_465 0.475566492022
# Wilson Ave @ Highland Ave_211 0.475268186023
# Warren St @ Woodbine St_10 0.474973138454
# Broadway @ Bay State Rd_435 0.474727016531
# Southern Artery opp Presidential Dr_225 0.474449449273
# Newburyport_CR-Newburyport 0.474246808479
# Manchester_CR-Newburyport 0.47416707624
# Water St @ Commercial St_222 0.474133947892
# Main St @ Hicks Ave_101 0.474012289648
# Washington St @ Broad St_225 0.473664882562
# Montvale Ave @ Main St_354 0.471598116612
# Lebanon St @ Valley St_106 0.470652350523
# Warren St @ Kearsarge Ave_10 0.470477037855
# Hayward St @ Shaw St_225 0.470338874487
# Main St @ Dexter St_101 0.470162557012
# O'Callaghan Way opp Osborne St_429 0.470098133527
# Main St @ Gay Ave_34E 0.469703877326
# Pleasant St @ Colonels Dr_222 0.46948862401
# Broadway @ Commonwealth Rd_435 0.468616007358
# Water St @ Myrtle St_222 0.468382645317
# Wheeler Rd @ Meadowbrook Rd_52 0.468366512742
# Nantasket Ave from Water St to Kenberma St (FLAG)_714 0.46809270352
# Opp 6 Water St_435 0.465032473841
# Opp 28 Water St_435 0.46306715088
# Parker St opp Wheeler Rd_52 0.462024618923
# Park Circle @ Park Ave_78 0.461330182975
# Mystic Ave @ Temple Rd_95 0.461217140831
# Bellevue Rd @ Spruce Rd_435 0.460396326227
# Gallivan Blvd @ Ross Rd_201 0.459486856721
# Circuit Dr @ Shattuck Hospital_195 0.454314403047
# Opp 43 W Dedham St_10 0.453311926586
# O'Callaghan Way @ Osborne St_426 0.45320879902
# Broadway @ Mayfair St_435 0.451086847864
# Hayward St opp Marietta Ave_225 0.450124442741
# Rowley_CR-Newburyport 0.446690622005
# Nantasket Ave from Kenburma St to A St (FLAG)_714 0.445443635373
# Broadway @ Warwick St_435 0.44034853976
# Chestnut St @ Boston St_435 0.440211136456
# Hayward St @ Marietta Ave_225 0.437235833999
# Broad St @ Middle St_222 0.435353834065
# Quincy Ave @ Southern Artery_225 0.432849241017
# Beverly Farms_CR-Newburyport 0.431288076694
# Main St @ Sherwood Dr._34E 0.42989231469
# Nantasket Ave from A St to Y St (FLAG)_714 0.423917612513
# Main St opp Chapman St_34E 0.422332161732
# Washington St opp Dean St_34E 0.419144246504
# 617 Lexington St_70A 0.418386916746
# Middle St @ Broad St_222 0.418052890156
# 6 Water St_465 0.410033237402
# Chestnut St @ Allerton St_435 0.407233683312
# Bellevue Rd @ Pine Rd_435 0.407061910145
# 22 Tapley St_435 0.406111184679
# 28 Water St_465 0.406104479141
# Main St @ Spear Ave_34E 0.405202840507
# Euclid Ave @ Clairmont St_435 0.404989183958
# Lexington St opp College Farm Rd_70A 0.403291717729
# Stoughton_CR-Providence 0.403095214863
# Nantasket Ave from Y St to Spring St (FLAG)_714 0.39968644305
# Salem St @ Allen Ct_95 0.397642971268
# Wash Blvd from Med Ctr to Rockland House Rd (FLAG)_714 0.396839525795
# Wash Blvd from Rockland House Rd to Med Ctr (FLAG)_714 0.396145332541
# Mystic Ave opp Kensington Ave_95 0.394589750879
# Rockport_CR-Newburyport 0.392983613266
# Euclid Ave @ Rockdale Ave_435 0.389058477467
# Mystic Ave opp Fellsway W_95 0.386987048058
# Washington St @ Oolah Ave_34E 0.383383991371
# Washington St @ Weld Ave_34E 0.381934653887
# Washington St @ Alandale Pkwy_34E 0.38127213379
# Washington St @ Concord Ave_34E 0.372772881076
# Spring St from Nantasket Ave to Main St (FLAG)_714 0.367698197155
# Broadway @ Lynnfield St_435 0.36640465874
# Gloucester_CR-Newburyport 0.366094978351
# Broadway @ Conomo Ave_435 0.365003455309
# Linwood St @ Ontario St_435 0.364280785557
# Tapley St @ Ontario St_435 0.363190187892
# Chestnut St opp Pond St_435 0.359161997592
# 219 Euclid Ave_435 0.35864870653
# Euclid Ave opp Lakeview Ave_435 0.357121648957
# West Gloucester_CR-Newburyport 0.347086322955
# Main St from Spring St to Pemberton Pnt (FLAG)_714 0.34516879714
# Parkland Ave @ Hurd St_435 0.332856823633
# Maple St @ Euclid Ave_435 0.33031734227
# Pemberton Point_714 0.329497999288
# Linwood St @ Parkland Ave_435 0.328890684594
# Chestnut St. @ Maple Street_435 0.310534862126
# Washington St @ Austin St_34E 0.308963106784
# Linwood St @ Hurd St_435 0.306562919083
# Euclid Ave @ Clayton St_435 0.301940412608
# Euclid Ave @ Verona St_435 0.301834408238
# Euclid Ave @ Chase St_435 0.29295723628
# 219 Linwood St_435 0.279742510248

# %%
def networkDebugging(graph):
    D_ij=0
    L_ij=0
    for node_i in graph.node():
        for node_j in graph.node():
            if node_i==node_j or graph.node()[node_i]['loc']==graph.node()[node_j]['loc']:
                continue
            d_ij = nx.shortest_path_length(graph,node_i,node_j,weight='Distance')
            shortestPath = nx.shortest_path(graph,node_i,node_j)
            d_ijCalc=0
            for i in range(1,len(shortestPath)):
                d_ijCalc+=euclidean_distance(graph.node()[shortestPath[i]]['loc'],graph.node()[shortestPath[i-1]]['loc'])
            d_ijReciprocal= d_ij**-1
            l_ij=euclidean_distance(graph.node()[node_i]['loc'],graph.node()[node_j]['loc'])
            l_ijReciprocal= l_ij**-1
            d_ijCalcReciprocal=d_ijCalc**-1
            if d_ijCalc<l_ij:
                print(node_i,node_j)
                print('Shortest path total length: ',d_ij)
                print('calculated shortest path:',d_ijCalc)
                print('Euclidean distance: ',l_ij)

            D_ij+=d_ijCalcReciprocal
            L_ij+=l_ijReciprocal
    return (D_ij/L_ij)

print(networkDebugging(subwayGraph))
# Out:
# 0.657676503248

# %%
#Full MBTA
n_Full = len(G.nodes())
l_Full = len(G.edges())
C_Full = nx.average_clustering(G)
#avgL_Full=nx.average_shortest_path_length(G)
connectedComponents_Full=len(list(nx.connected_components(G)))

print('|N_Monoplex|={0}'.format(n_Full))
print('|L_Monoplex|={0}'.format(l_Full))
print('<C_Full>={0}'.format(C_Full))
#print('<d>={0}'.format(avgL_Full))
print('|Connected Components|={0}'.format(connectedComponents_Full))

#Develop degree distribution plot and plot on log-log scale
degDistFull=pd.DataFrame(pd.Series(list(dict(G.degree()).values())).value_counts()).reset_index().rename(columns = {'index':'k',0:'p_k'})
degDistFull.p_k=degDistFull.p_k/degDistFull.p_k.sum()
degDistFull.plot(x='k',y='p_k',kind='scatter',loglog=True,figsize=(10,6))
fit = powerlaw.Fit(degDistFull.k)
print('degree gamma: {0}'.format(fit.alpha))
plt.xlabel('Degree (k)')
plt.ylabel('Degree Distribution (p_k)')
plt.title('Degree Distribution for the Monoplex MBTA Network (N=4521)')
plt.savefig('MBTA_Deg.png')

wDistFull=pd.DataFrame(pd.Series([round(G.get_edge_data(e[0],e[1])['Distance'],2) for e in G.edges(data=True)]).value_counts()).reset_index().rename(columns = {'index':'w',0:'p_w'})
wDistFull.p_w=wDistFull.p_w/wDistFull.p_w.sum()
fit = powerlaw.Fit(wDistFull.w.loc[wDistFull.w!=0.0])
#fit.plot_pdf(color = 'g', linestyle='--', label = 'power law fit')
print('weight gamma: {0}'.format(fit.alpha))
wDistFull.loc[wDistFull.w!=0.0].plot(x='w',y='p_w',kind='scatter',loglog=True,figsize=(10,6))
plt.xlabel('Weight (w)')
plt.ylabel('Weight Distribution (w_k)')
plt.title('Weight Distribution for the Monoplex MBTA Network')
plt.savefig('MBTA_Weight.png')
# Out:
# |N_Monoplex|=4521
# |L_Monoplex|=5582
# <C_Full>=0.04959269023635314
# |Connected Components|=1
# degree gamma: 3.497220762322735
# Calculating best minimal value for power law fit
# C:\Users\ibiyt\Anaconda3\lib\site-packages\powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# Calculating best minimal value for power law fit
# weight gamma: 5.193414763016407

# %%
CC=nx.clustering(G)
deg=dict(G.degree())
cKDistFull=pd.DataFrame(pd.Series(deg)).reset_index().rename(columns={'index':'Stop',0:'k'})
df=pd.DataFrame(pd.Series(CC).reset_index()).rename(columns={'index':'Stop',0:'C(k)'})
cKDistFull=cKDistFull.merge(df,how='inner',on='Stop').drop('Stop',axis=1)
cKDistFull.plot(x='k',y='C(k)',kind='scatter',loglog=True,figsize=(10,6))
plt.xlabel('Degree (k)')
plt.ylabel('Clustering Coefficient Distribution C(k)')
plt.title('Local Clustering Coefficient Distribution for MBTA Monoplex Network <C>=0.04959269023635314')
plt.savefig('MBTA_CC.png')

CC=nx.clustering(subwayGraph)
deg=dict(subwayGraph.degree())
cKDistFull=pd.DataFrame(pd.Series(deg)).reset_index().rename(columns={'index':'Stop',0:'k'})
df=pd.DataFrame(pd.Series(CC).reset_index()).rename(columns={'index':'Stop',0:'C(k)'})
cKDistFull=cKDistFull.merge(df,how='inner',on='Stop').drop('Stop',axis=1)
cKDistFull.plot(x='k',y='C(k)',kind='scatter',loglog=True,figsize=(10,6))
plt.xlabel('Degree (k)')
plt.ylabel('Clustering Coefficient Distribution C(k)')
plt.title('Local Clustering Coefficient Distribution for MBTA Rapid Transit Network <C>=0.017811704834605594')
plt.savefig('sub_CC.png')

CC=nx.clustering(busGraph)
deg=dict(busGraph.degree())
cKDistFull=pd.DataFrame(pd.Series(deg)).reset_index().rename(columns={'index':'Stop',0:'k'})
df=pd.DataFrame(pd.Series(CC).reset_index()).rename(columns={'index':'Stop',0:'C(k)'})
cKDistFull=cKDistFull.merge(df,how='inner',on='Stop').drop('Stop',axis=1)
cKDistFull.plot(x='k',y='C(k)',kind='scatter',loglog=True,figsize=(10,6))
plt.xlabel('Degree (k)')
plt.ylabel('Clustering Coefficient Distribution C(k)')
plt.title('Local Clustering Coefficient Distribution for MBTA Bus Network <C>=0.026062837725154508')
plt.savefig('bus_CC.png')

CC=nx.clustering(crGraph)
deg=dict(crGraph.degree())
cKDistFull=pd.DataFrame(pd.Series(deg)).reset_index().rename(columns={'index':'Stop',0:'k'})
df=pd.DataFrame(pd.Series(CC).reset_index()).rename(columns={'index':'Stop',0:'C(k)'})
cKDistFull=cKDistFull.merge(df,how='inner',on='Stop').drop('Stop',axis=1)
cKDistFull.plot(x='k',y='C(k)',kind='scatter',loglog=True,figsize=(10,6))
plt.xlabel('Degree (k)')
plt.ylabel('Clustering Coefficient Distribution C(k)')
plt.title('Local Clustering Coefficient Distribution for MBTA Commuter Rail Network <C>=0.029761904761904757')
plt.savefig('cr_CC.png')

# %%
list(nx.neighbors(G,'250 Dorchester Avenue_9'))
# Out:
# ['Broadway_Red', 'Andrew_Red']

# %%
#Subway Network Characteristics
n_Subway = len(subwayGraph.nodes())
l_Subway = len(subwayGraph.edges())
C_Subway = nx.average_clustering(subwayGraph)
connectedComponents_Subway=len(list(nx.connected_components(subwayGraph)))

print('|N_Subway|={0}'.format(n_Subway))
print('|L_Subway|={0}'.format(l_Subway))
print('|C_Subway|={0}'.format(C_Subway))
print('|Connected Components|={0}'.format(connectedComponents_Subway))

#Develop degree distribution plot and plot on log-log scale
degDistSubway=pd.DataFrame(pd.Series(list(dict(subwayGraph.degree()).values())).value_counts()).reset_index().rename(columns = {'index':'k',0:'p_k'})
degDistSubway.p_k=degDistSubway.p_k/degDistSubway.p_k.sum()
degDistSubway.plot(x='k',y='p_k',kind='scatter',loglog=True,figsize=(10,6))
fit = powerlaw.Fit(degDistSubway.k)
#fit.plot_pdf(color = 'g', linestyle='--', label = 'power law fit')
print('degree gamma: {0}'.format(fit.alpha))
plt.xlabel('Degree (k)')
plt.ylabel('Degree Distribution (p_k)')
plt.title('Degree Distribution for the MBTA Rapid Transit Network (N=131)')
plt.savefig('Sub_Deg.png')

wDistSubway=pd.DataFrame(pd.Series([round(subwayGraph.get_edge_data(e[0],e[1])['Distance'],2) for e in subwayGraph.edges(data=True)]).value_counts()).reset_index().rename(columns = {'index':'w',0:'p_w'})
wDistSubway.p_w=wDistSubway.p_w/wDistSubway.p_w.sum()
fit = powerlaw.Fit(wDistSubway.w.loc[wDistSubway.w!=0.0])
#fit.plot_pdf(color = 'g', linestyle='--', label = 'power law fit')
print('weight gamma: {0}'.format(fit.alpha))
wDistSubway.loc[wDistSubway.w!=0.0].plot(x='w',y='p_w',kind='scatter',loglog=True,figsize=(10,6))
plt.xlabel('Weight (w)')
plt.ylabel('Weight Distribution (w_k)')
plt.title('Weight Distribution for the MBTA Rapid Transit Network')
plt.savefig('Sub_W.png')
# Out:
# |N_Subway|=131
# |L_Subway|=133
# |C_Subway|=0.017811704834605594
# |Connected Components|=1
# degree gamma: 2.2586319217765
# weight gamma: 3.2697081482462975
# Calculating best minimal value for power law fit
# C:\Users\ibiyt\Anaconda3\lib\site-packages\powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# Calculating best minimal value for power law fit

# %%
#Bus Network Characteristics
n_Bus = len(busGraph.nodes())
l_Bus = len(busGraph.edges())
C_Bus = nx.average_clustering(busGraph)
connectedComponents_Bus=len(list(nx.connected_components(busGraph)))

print('|N_Bus|={0}'.format(n_Bus))
print('|L_Bus|={0}'.format(l_Bus))
print('|C_Bus|={0}'.format(C_Bus))
print('|Connected Components_Bus|={0}'.format(connectedComponents_Bus))

#Develop degree distribution plot and plot on log-log scale
degDistBus=pd.DataFrame(pd.Series(list(dict(busGraph.degree()).values())).value_counts()).reset_index().rename(columns = {'index':'k',0:'p_k'})
degDistBus.p_k=degDistBus.p_k/degDistBus.p_k.sum()
degDistBus.plot(x='k',y='p_k',kind='scatter',loglog=True,figsize=(10,6))
fit = powerlaw.Fit(degDistBus.k)
print('degree gamma: {0}'.format(fit.alpha))
plt.xlabel('Degree (k)')
plt.ylabel('Degree Distribution (p_k)')
plt.title('Degree Distribution for the MBTA Bus Network (N=4395)')
plt.savefig('Bus_Deg.png')

wDistBus=pd.DataFrame(pd.Series([round(busGraph.get_edge_data(e[0],e[1])['Distance'],2) for e in busGraph.edges(data=True)]).value_counts()).reset_index().rename(columns = {'index':'w',0:'p_w'})
wDistBus.p_w=wDistBus.p_w/wDistBus.p_w.sum()
fit = powerlaw.Fit(wDistBus.w.loc[wDistBus.w!=0.0])
#fit.plot_pdf(color = 'g', linestyle='--', label = 'power law fit')
print('weight gamma: {0}'.format(fit.alpha))
wDistBus.loc[wDistBus.w!=0.0].plot(x='w',y='p_w',kind='scatter',loglog=True,figsize=(10,6))
plt.xlabel('Weight (w)')
plt.ylabel('Weight Distribution (w_k)')
plt.title('Weight Distribution for the MBTA Bus Network')
plt.savefig('Bug_W.png')
# Out:
# |N_Bus|=4395
# |L_Bus|=4974
# |C_Bus|=0.026062837725154508
# |Connected Components_Bus|=1
# degree gamma: 3.806950486715729
# Calculating best minimal value for power law fit
# C:\Users\ibiyt\Anaconda3\lib\site-packages\powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# Calculating best minimal value for power law fit
# weight gamma: 4.305093284189859

# %%
#Commuter Rail Network Characteristics
n_CR = len(crGraph.nodes())
l_CR = len(crGraph.edges())
C_CR = nx.average_clustering(crGraph)
connectedComponents_CR=len(list(nx.connected_components(crGraph)))

print('|N_CR|={0}'.format(n_CR))
print('|L_CR|={0}'.format(l_CR))
print('|C_CR|={0}'.format(C_CR))
print('|Connected Components_CR|={0}'.format(connectedComponents_CR))

#Develop degree distribution plot and plot on log-log scale
degDistCR=pd.DataFrame(pd.Series(list(dict(crGraph.degree()).values())).value_counts()).reset_index().rename(columns = {'index':'k',0:'p_k'})
degDistCR.p_k=degDistCR.p_k/degDistCR.p_k.sum()
degDistCR.plot(x='k',y='p_k',kind='scatter',loglog=True,figsize=(10,6))
fit = powerlaw.Fit(degDistCR.k)
print('degree gamma: {0}'.format(fit.alpha))
plt.xlabel('Degree (k)')
plt.ylabel('Degree Distribution (p_k)')
plt.title('Degree Distribution for the MBTA Commuter Rail Network (N=140)')
plt.savefig('CR_Deg.png')

wDistCR=pd.DataFrame(pd.Series([round(crGraph.get_edge_data(e[0],e[1])['Distance'],2) for e in crGraph.edges(data=True)]).value_counts()).reset_index().rename(columns = {'index':'w',0:'p_w'})
wDistCR.p_w=wDistCR.p_w/wDistCR.p_w.sum()
fit = powerlaw.Fit(wDistCR.w.loc[wDistCR.w!=0.0])
#fit.plot_pdf(color = 'g', linestyle='--', label = 'power law fit')
print('weight gamma: {0}'.format(fit.alpha))
wDistCR.loc[wDistCR.w!=0.0].plot(x='w',y='p_w',kind='scatter',loglog=True,figsize=(10,6))
plt.xlabel('Weight (w)')
plt.ylabel('Weight Distribution (w_k)')
plt.title('Weight Distribution for the MBTA Commuter Rail Network')
plt.savefig('CR_W.png')
# Out:
# |N_CR|=140
# |L_CR|=144
# |C_CR|=0.029761904761904757
# |Connected Components_CR|=2
# degree gamma: 2.2586319217765
# weight gamma: 2.6056203278353536
# Calculating best minimal value for power law fit
# C:\Users\ibiyt\Anaconda3\lib\site-packages\powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# Calculating best minimal value for power law fit

# %%
avgLMBTA=nx.average_shortest_path_length(G)
avgLSub=nx.average_shortest_path_length(subwayGraph)
avgLBus=nx.average_shortest_path_length(busGraph)
crGraphComponents=list(nx.connected_component_subgraphs(crGraph))
avgLCR1=nx.average_shortest_path_length(crGraphComponents[0])
avgLCR2=nx.average_shortest_path_length(crGraphComponents[1])
print(avgLMBTA, avgLSub, avgLBus, avgLCR1,avgLCR2)
# Out:
# 26.500054612398777 15.236876100998238 44.41382016950408 11.11352002408913 13.214761040532366

# %%
[len(x) for x in crGraphComponents]
# Out:
# [82, 58]

# %%
print(np.mean(list(dict(G.degree()).values())),np.mean(list(dict(subwayGraph.degree()).values())),np.mean(list(dict(busGraph.degree()).values())),np.mean(list(dict(crGraph.degree()).values())))
# Out:
# 2.47467374475 2.03053435115 2.26348122867 2.05714285714

# %%
subgraph=nx.subgraph(G,list(G.nodes())[:100])
connected_subgraph=list(nx.connected_component_subgraphs(subgraph))[2]
connected_subgraph['North Quincy_Red']
# Out:
# AtlasView({'JFK/UMASS_Red-Ashmont': {'Subway': True, 'Distance': 0.050816069938550042}, 'Hancock St @ Woodbine St_Red': {'Subway': True, 'Distance': 0.014698453558118428}, 'North Quincy_Red': {'Subway': True, 'Distance': 0.0017741550101383504}})

# %%
for node in G.nodes():
    
    if node=='North Quincy_Red':
        print(G.nodes()[node])
# Out:
# {'Subway': True, 'loc': (-71.029583, 42.275275), 'contraction': {'N Quincy @ Red Line_211': {'Bus': True, 'loc': (-71.029583, 42.275275)}, 'N Quincy @ Red Line_215': {'Bus': True, 'loc': (-71.029583, 42.275275)}, 'N Quincy @ Red Line_201': {'Bus': True, 'loc': (-71.029583, 42.275275)}, 'N Quincy @ Red Line_210': {'Bus': True, 'loc': (-71.029583, 42.275275)}, 'N Quincy @ Red Line_217': {'Bus': True, 'loc': (-71.029583, 42.275275)}, 'N Quincy @ Red Line_212': {'Bus': True, 'loc': (-71.029583, 42.275275)}, 'N Quincy @ Red Line_202': {'Bus': True, 'loc': (-71.029583, 42.275275)}}, 'Efficiency': 0.81094189451106213}

# %%
def nullModel(graph,weight):
    '''
    Develops null models using modified degree randomization. Our modifications currently only have a distance threshold of 0.5
    '''
    graphCopy=graph.copy()
    time=len(graphCopy)
    meanK=np.mean(list(dict(graphCopy.degree()).values()))
    for i in range(len(graphCopy.edges())):
        if i%1000==0:
            print(i)
        edges, swap=doSwap(graphCopy)
        while graphCopy.has_edge(swap[0][0],swap[0][1]) or graphCopy.has_edge(swap[1][0],swap[1][1]): 
            edges, swap=doSwap(graphCopy)
        graphCopy.remove_edges_from(edges)
        graphCopy.add_edges_from(swap)
    return graphCopy
        
        
def doSwap(graph):
    edges=random.sample(graph.edges(),2)
    g=nx.Graph()
    g.add_edges_from(edges)
    while edges[0]==edges[1] or len(g.nodes())<4 or maxEuclid(edges,graph):
            edges=random.sample(graph.edges(),2)
            g=nx.Graph()
            g.add_edges_from(edges)
    gCopy=nx.double_edge_swap(g)
    swap=list(gCopy.edges())
    return edges, swap
def maxEuclid(e,graph):
    if euclidean_distance(graph.nodes()[e[0][0]]['loc'],graph.nodes()[e[1][0]]['loc'])>=0.03 or euclidean_distance(graph.nodes()[e[0][0]]['loc'],graph.nodes()[e[1][1]]['loc'])>=0.03 or euclidean_distance(graph.nodes()[e[0][1]]['loc'],graph.nodes()[e[1][0]]['loc'])>=0.03 or euclidean_distance(graph.nodes()[e[0][1]]['loc'],graph.nodes()[e[1][1]]['loc'])>=0.03:
        return True
    else:
        return False
start=time.time()
null=nullModel(G,'Distance')
print(time.time()-start)
# degDistNull=pd.DataFrame(pd.Series(list(dict(null.degree()).values())).value_counts()).reset_index().rename(columns = {'index':'k',0:'p_k'})
# degDistNull.p_k=degDistNull.p_k/degDistNull.p_k.sum()
# degDistNull.plot(x='k',y='p_k',kind='scatter',loglog=True,figsize=(10,6))
# fit = powerlaw.Fit(degDistNull.k)
# print('degree gamma: {0}'.format(fit.alpha))
# plt.xlabel('Degree (k)')
# plt.ylabel('Degree Distribution (p_k)')
# plt.title('Degree Distribution for the Null Network (N=4395)')
# plt.savefig('Bus_Deg.png')
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 860.1717579364777

# %%
def f(x):
    return x*x
def getNullModels():
    with Pool(processes=4) as pool:
        return pool.map(f, range(10))

getNullModels()

# %%
modes=[key for key in G.nodes()['Kenmore_Green-B'] if key=='Subway' or key=='Bus' or key=='Commuter_Rail']
modes.extend([[x for x in G.nodes()['Kenmore_Green-B']['contraction'][key] if x in ['Subway','Bus','Commuter_Rail']][0] for key in G.nodes()['Kenmore_Green-B']['contraction']])
modes=np.unique(modes)
print(modes)
modes.sort()
modes
# Out:
# ['Bus' 'Subway']
# array(['Bus', 'Subway'],
#       dtype='<U6')
